# %% [markdown]
# # Recent Email Marketing Campaign Data

# %% [markdown]
# - A welcome message to new subscribers, originally sent this past Monday, September 30th, and re-sent yesterday, October 2nd: https://tinyurl.com/28ctea5p
# - A success story message sent to recently added existing subscribers, originally sent last Thursday, September 25th, and re-sent on Friday, September 27th: https://tinyurl.com/3u3dyxu6
#
#
# - Highlight the respective engagement levels for each message, based on their open and click data (i.e., organize the contacts by their open & click-related activity, from most often to least often)
# - Highlight the respective focus areas for the aforementioned contacts, so we can see which areas are most interested in our services

# %%
# import required libraries
import pandas as pd
import datetime

# %%
# Read all excel sheets

# Welcome Message
original_clicked_df = pd.read_excel('New-Sub-Message/New Subscriber Message - Original Clicked.xlsx')
original_opened_df = pd.read_excel('New-Sub-Message/New Subscriber Message - Original Opened.xlsx')
resent_clicked_df = pd.read_excel('New-Sub-Message/New Subscriber Message - Re-send Clicked.xlsx')
resent_opened_df = pd.read_excel('New-Sub-Message/New Subscriber Message - Re-send Opened.xlsx')

# Success Story
ss_original_clicked_df = pd.read_excel('Success Story Message/Success Story Message - Original Clicked.xlsx')
ss_original_opened_df = pd.read_excel('Success Story Message/Success Story Message - Original Opened.xlsx')
ss_resend_clicked_df = pd.read_excel('Success Story Message/Success Story Message - Re-send Clicked.xlsx')
ss_resend_opened_df = pd.read_excel('Success Story Message/Success Story Message - Re-send Opened.xlsx')

# %% [markdown]
# ### Engagement Levels for Message 1 - Welcome Message (Sent 11/2024, Resent 10/2/24)

# %% [markdown]
# ##### Exploratory Data Analysis

# %%
# Created a dataframe that includes all excel sheets for message 1
welcome_message_df = pd.concat([original_clicked_df, original_opened_df, resent_clicked_df, resent_opened_df])
welcome_message_df
# Out:
#                        Email address First name    Last name  \
# 0                chrt-info@umich.edu   Terrisca  Des Jardins
# 1                chrt-info@umich.edu   Terrisca  Des Jardins
# 2                chrt-info@umich.edu   Terrisca  Des Jardins
# 3                chrt-info@umich.edu   Terrisca  Des Jardins
# 4                chrt-info@umich.edu   Terrisca  Des Jardins
# ..                               ...        ...          ...
# 83  statesboroexchangeclub@gmail.com    Christy      Kennedy
# 84  wcharles@brightfutureforkids.com      Widza     Robinson
# 85             wi.arvssweb@yahoo.com      Ellen     Thomford
# 86             wi.arvssweb@yahoo.com      Ellen     Thomford
# 87         zach@broadleafwriters.com    Zachary       Stevie
#
#                                               Company  \
# 0   CENTER FOR HEALTHCARE RESEARCH AND TRANSFORMATION
# 1   CENTER FOR HEALTHCARE RESEARCH AND TRANSFORMATION
# 2   CENTER FOR HEALTHCARE RESEARCH AND TRANSFORMATION
# 3   CENTER FOR HEALTHCARE RESEARCH AND TRANSFORMATION
# 4   CENTER FOR HEALTHCARE RESEARCH AND TRANSFORMATION
# ..                                                ...
# 83     NATIONAL EXCHANGE CLUB STATESBORO GA CLUB 2588
# 84                         Bright Future For Kids Inc
# 85        Animal Rescue & Veterinary Support Services
# 86        Animal Rescue & Veterinary Support Services
# 87                 Broadleaf Writers Association Inc.
#
#                                  Clicked Link Address        Clicked At  \
# 0                https://group22team.com/testimonials  9/30/2024 8:20am
# 1         https://www.instagram.com/group22nonprofit/  9/30/2024 8:20am
# 2               https://group22team.com/nonprofithelp  9/30/2024 8:20am
# 3                https://group22team.com/gold-package  9/30/2024 8:20am
# 4   https://calendly.com/marcusgroup22/free-consul...  9/30/2024 8:20am
# ..                                                ...               ...
# 83                                                NaN               NaN
# 84                                                NaN               NaN
# 85                                                NaN               NaN
# 86                                                NaN               NaN
# 87                                                NaN               NaN
#
#             Opened At
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ..                ...
# 83   10/2/2024 8:30am
# 84   10/2/2024 8:31am
# 85  10/2/2024 11:24pm
# 86   10/2/2024 8:45am
# 87   10/2/2024 8:48am
#
# [1444 rows x 7 columns]

# %%
# Checked size of the dataframe
welcome_message_df.shape
# Out:
# (1444, 7)

# %%
# Checked data type 
welcome_message_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1444 entries, 0 to 87
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Email address         1444 non-null   object
#  1   First name            1444 non-null   object
#  2   Last name             1432 non-null   object
#  3   Company               1210 non-null   object
#  4   Clicked Link Address  76 non-null     object
#  5   Clicked At            76 non-null     object
#  6   Opened At             1368 non-null   object
# dtypes: object(7)
# memory usage: 90.2+ KB

# %% [markdown]
# ##### Engagement Levels

# %%
# Created a dictionary containing all emails in the dataset as well as how often they appear
email_count = {}
multiple_instances = []

for email in welcome_message_df["Email address"]:
    if email in email_count:
        email_count[email] += 1
    else:
        email_count[email] = 1

email_count
# Out:
# {'chrt-info@umich.edu': 7,
#  'director@sherishoh.org': 4,
#  'foundation@pistons.com': 6,
#  'info@bookwormgardens.org': 7,
#  'info@ceri.org': 5,
#  'info@fredgoodwill.org': 7,
#  'info@galesburgarts.org': 7,
#  'info@nbnfoundation.us': 8,
#  'info@oberkotterfoundation.org': 6,
#  'info@parishresourcecenter.org': 4,
#  'info@pcacareconnections.org': 7,
#  'info@rappahannockunitedway.org': 6,
#  'info@refed.org': 10,
#  'info@riverrangers.org': 4,
#  'info@rw-c.org': 7,
#  'info@smemnm.org': 6,
#  'meupton@worldpartnerships.org': 5,
#  'ocof@onecommunityonefamily.org': 6,
#  'social@detroitregionalpartnership.com': 7,
#  '1860farm@gmail.com': 1,
#  '304gaf@gmail.com': 1,
#  '67help@co.genesee.mi.us': 1,
#  '75kambly@gmail.com': 2,
#  'abbysfriends@homesc.com': 2,
#  'admack@gibbesmuseum.org': 1,
#  'admissions@berry.edu': 1,
#  'adopt@ctdr.org': 1,
#  'adriann_young@nobl.k12.in.us': 1,
#  'ads@baptistcourier.com': 1,
#  'advancement@cmich.edu': 1,
#  'advancement@hillelacademytampa.com': 1,
#  'ahales@communitiesaligned.org': 4,
#  'ahpd_info@ahpd.org': 1,
#  'alecbrown55@gmail.com': 1,
#  'amiller@bryanareafoundation.org': 1,
#  'andrew@abbevillecountyhistoricalsociety.org': 1,
#  'angela@caanderson.org': 3,
#  'angie.mollenkopf@nvm.org': 4,
#  'anotherchance4animals@gmail.com': 4,
#  'applications@gsrescue1.org': 1,
#  'aserna@cityonahillmilwaukee.org': 1,
#  'ashleysangelsinc@gmail.com': 2,
#  'ashlyn@firstteescw.org': 1,
#  'ashwaubenoncooppreschool@gmail.com': 1,
#  'askus@wnpl.info': 1,
#  'assoc.manager@nacdep.net': 2,
#  'baf@brunswickathleticfoundation.org': 3,
#  'bcumchurch@gmail.com': 2,
#  'berniolson@rappbenfund.org': 2,
#  'biblefree@yahoo.com': 1,
#  'birdies4breastcancercare@gmail.com': 1,
#  'blackpearltn2018@gmail.com': 2,
#  'blair@rangermemorial.org': 2,
#  'bon@billgrahamfoundation.org': 2,
#  'borntoreadec@gmail.com': 1,
#  'boscobeledfoundation@gmail.com': 1,
#  'bowsoffice@beyondourwalls.org': 3,
#  'boxoffice@santafeplayhouse.org': 2,
#  'brcg.rohingya@gmail.com': 3,
#  'brianasheartofgold@gmail.com': 2,
#  'bridgeofhopeincchicago@gmail.com': 3,
#  'brightsideyouthranch@gmail.com': 1,
#  'brokengroundschurch@gmail.com': 1,
#  'brownbagfoodproject@gmail.com': 2,
#  'brownhelmhistory@gmail.com': 1,
#  'brunswickeducationfoundation@gmail.com': 1,
#  'buildalegacyinc@gmail.com': 2,
#  'bullymenotfoundation@gmail.com': 1,
#  'burgundy.hill@1qct.org': 1,
#  'cafabecky@gmail.com': 2,
#  'caffj@chicagoappleseed.org': 4,
#  'camaga.atlanta@gmail.com': 2,
#  'camp.jewell@ghymca.org': 1,
#  'camp@campquest.org': 2,
#  'campadamfisher@gmail.com': 1,
#  'capntally@gmail.com': 2,
#  'captsampat@embarqmail.com': 1,
#  'caringhearts@thriftshop.network': 2,
#  'casipets@sbcglobal.net': 2,
#  'catalystclc1@gmail.com': 2,
#  'catherinejonesministries@gmail.com': 1,
#  'ccritchlow@rrlcschool.org': 1,
#  'cdanforth@capricommunities.com': 1,
#  'cdcc2011@gmail.com': 1,
#  'cedarrapids@countryhouse.net': 2,
#  'celticcovecatholic@gmail.com': 3,
#  'centralgeorgiaautism@gmail.com': 1,
#  'centroaztlan@sbcglobal.net': 1,
#  'ceo@afathersplace.org': 1,
#  'ceo@freedomfoundation.com': 1,
#  'chambleecopnstuff@gmail.com': 1,
#  'chc@centex.net': 2,
#  'chief38@comcast.net': 1,
#  'childsafe@childsafe-sa.org': 1,
#  'christine@shevlinfamilyfoundation.org': 1,
#  'christmasinjulycharitywi@gmail.com': 3,
#  'cindy@camphappydays.com': 1,
#  'cleburnefca@gmail.com': 1,
#  'clientservices@suwanneeec.net': 1,
#  'cmc@centralmichigancare.com': 2,
#  'cmcgee@familycenters.org': 1,
#  'cmsa@cmsa.org': 1,
#  'cnaparalla@waupacaschools.org': 2,
#  'coastalbendfb@coastalbendfoodbank.org': 3,
#  'cocohoustonnow@gmail.com': 1,
#  'communications@bufordcityschools.org': 2,
#  'communications@nhnga.org': 1,
#  'communications@stah.org': 1,
#  'communications@swancitysc.com': 1,
#  'communications@tsc.fl.edu': 1,
#  'communityforchildren@gmail.com': 1,
#  'connect@geccf.org': 1,
#  'connect@pantheontheatre.org': 7,
#  'contact@arisemke.org': 2,
#  'contact@benjacksonfoundation.org': 1,
#  'contact@beyondabuse.info': 1,
#  'contact@chestnutarts.org': 2,
#  'contact@creativedoc.org': 1,
#  'contact@furagoodpaws.org': 1,
#  'contact@givenkind.org': 2,
#  'contact@gordoncountychamber.com': 4,
#  'contact@historyandnature.org': 1,
#  'contact@kgsymphony.org': 1,
#  'contact@newchurchesnow.org': 3,
#  'contact@oakmanor.org': 1,
#  'contact@pennmanoredfoundation.org': 1,
#  'contact@pmaaems.org': 2,
#  'contact@rhythmx.org': 3,
#  'contact@risingstarlearningcenter.com': 1,
#  'contact@scmrcd.org': 1,
#  'contact@supportnef.org': 1,
#  'contact@synapticsparks.org': 2,
#  'contact@thepeacemakercenter.org': 1,
#  'contact@yminstitute.com': 1,
#  'contactus@bellagail.org': 2,
#  'contactus@qcdc.org': 1,
#  'corp@blackpush.org': 1,
#  'cover6outdoors@gmail.com': 2,
#  'crosscreekmeadows@gmail.com': 1,
#  'crossthreadsthrift@gmail.com': 1,
#  'cstkinformation@gmail.com': 2,
#  'ctritch@newhavencarecenter.org': 1,
#  'cullinanparkconservancy@gmail.com': 1,
#  'curator@kelsohouse.org': 1,
#  'cure.local@gmail.com': 1,
#  'customerservice@rsna.org': 1,
#  'cwalterhouse@sb.school': 1,
#  'dames@nscda.org': 1,
#  'dave@cowboyshelpingcowboys.com': 1,
#  'dave@r3development.org': 2,
#  'david@bisfoundation.net': 2,
#  'dcox@ahla.com': 3,
#  'derekc@chileda.org': 1,
#  'development@cathedral-center.org': 2,
#  'development@cbrrescue.org': 2,
#  'development@detroitpal.org': 1,
#  'development@girlsinthegame.org': 1,
#  'dgorski@caritas.us': 1,
#  'dhanimalrescue@gmail.com': 3,
#  'dhoughton@wildlandscapes.org': 1,
#  'dhwegener.ntca@gmail.com': 1,
#  'dir@nccs-inc.org': 1,
#  'director@boltonrefuge.org': 1,
#  'director@campk.net': 1,
#  'director@cctaonline.org': 2,
#  'director@glencoeyouthservices.org': 1,
#  'director@globalallianceafrica.org': 1,
#  'director@locker505.org': 2,
#  'director@quincycatholicschools.org': 5,
#  'dist12@ptd.net': 2,
#  'donate@reachoutcc.org': 3,
#  'donations@garfieldpark.org': 2,
#  'drkfitz52@gmail.com': 1,
#  'dsingh@pediamanor.org': 1,
#  'edenrecoveryhouse@gmail.com': 4,
#  'editor@nam-math.org': 5,
#  'ellen@beloitmealsonwheels.org': 1,
#  'email@santafe.edu': 1,
#  'equity.officer@sfcollege.edu': 1,
#  'erika@corazonsa.org': 1,
#  'evonn@zoeloren.org': 1,
#  'exec@blackpine.org': 1,
#  'exec@wpdaynursery.org': 1,
#  'executivedirector@geyfcs.org': 1,
#  'fiestaparades@gmail.com': 2,
#  'fleenor@nomadchurch.org': 1,
#  'foundation@gailborden.info': 1,
#  'foundation@hccfl.edu': 1,
#  'foundation@rbha.org': 2,
#  'foundation@wil-power.org': 1,
#  'foundation@ysfpb.org': 5,
#  'fredakalinateam@gmail.com': 1,
#  'fredgreen@hpnfc.org': 2,
#  'frontdesk@readcenter.org': 1,
#  'frontdesk@restonchildrenscenter.org': 2,
#  'frontdesk@richlandacademy.com': 1,
#  'furangelsanimalsanctuary@gmail.com': 3,
#  'futures@futuresunlimited.org': 1,
#  'galenafd@sbcglobal.net': 1,
#  'galesburgrotary@gmail.com': 2,
#  'gallery510@sbcglobal.net': 4,
#  'garridostrayrescue@gmail.com': 1,
#  'gates.vols@gmail.com': 1,
#  'gaylordhighschoolhockey@gmail.com': 1,
#  'gbnbooster@gmail.com': 1,
#  'gcfmc@comcast.net': 1,
#  'gcouncilchicago@gmail.com': 1,
#  'gcs@geneseechristianschool.com': 1,
#  'gdarling@daytonfoundation.org': 1,
#  'geethamandalam1978@gmail.com': 1,
#  'general-info@roottrj.org': 2,
#  'generoushands24@gmail.com': 1,
#  'geneseecountyhistoricalsociety@gmail.com': 1,
#  'geneseetownship@geneseetwpmi.gov': 1,
#  'geneseoeducation1@gmail.com': 2,
#  'geneseopantry@gmail.com': 1,
#  'genesisoutreachministriesintl@gmail.com': 1,
#  'genevafoundation@presbyterianhomes.org': 1,
#  'george@swop.net': 1,
#  'getinfo@genesisschools.org': 1,
#  'gibbsl@capetigers.com': 1,
#  'gibsonton.elementary@hcps.net': 1,
#  'givingdupage@dupagecounty.gov': 1,
#  'gjohnson@benedictcenter.org': 2,
#  'gjones@skyymca.org': 1,
#  'glencoeptocentral@gmail.com': 2,
#  'glenellyninfantwelfare@gmail.com': 6,
#  'glenellynrotary@gmail.com': 1,
#  'glenhagenfarm@gmail.com': 1,
#  'globalaction@globalaction.com': 1,
#  'gmsnorthpto@gmail.com': 1,
#  'gplfoundation1930@gmail.com': 2,
#  'grants@gamechangers.film': 1,
#  'grants@santafefilminstitute.org': 1,
#  'groupevents@tottrg.com': 5,
#  'hbpublicrecords@highlandbeach.us': 1,
#  'hces@stjohns.k12.fl.us': 1,
#  'hcfrpublicrelations@hcfl.gov': 1,
#  'heather@reesestronginc.com': 3,
#  'hello@beautifulgatecenter.org': 4,
#  'hello@neveralonewidows.com': 4,
#  'hello@odcenter.org': 1,
#  'hello@pennair.com': 2,
#  'hello@thecovewaco.org': 1,
#  'help@countyhealthplans.org': 1,
#  'help@nationalinfantryfoundation.org': 1,
#  'help@nbmbaa.org': 1,
#  'hhsrowingclub@gmail.com': 5,
#  'highlands4h@ifas.ufl.edu': 1,
#  'historyrhs@gmail.com': 1,
#  'hophampton@gmail.com': 1,
#  'hpgcc@hpgcc.com': 1,
#  'iieresearch@iie.org': 1,
#  'imamadly1@yahoo.com': 1,
#  'info.nsasavannah@gmail.com': 1,
#  'info@1049theriver.com': 1,
#  'info@acabroadway.com': 1,
#  'info@amazed15.org': 1,
#  'info@arborplaceinc.org': 1,
#  'info@arc-southeast.org': 1,
#  'info@bdlia.org': 2,
#  'info@becauseofkennedy.org': 1,
#  'info@becauseonematters.org': 1,
#  'info@beloitartcenter.com': 4,
#  'info@belovedatlanta.org': 2,
#  'info@benjamins-house.org': 1,
#  'info@bestower.org': 1,
#  'info@beth-el.org': 2,
#  'info@blackcreek-cc.com': 1,
#  'info@blackrosefoundation.org': 1,
#  'info@blackvotersmatterfund.org': 1,
#  'info@blessingsworkingtogether.org': 1,
#  'info@blueribbonschools.com': 1,
#  'info@bridgingtheway.org': 2,
#  'info@brightontheirworld.org': 1,
#  'info@brigidspath.org': 1,
#  'info@brokenchainsministry.org': 1,
#  'info@brookhavencommerce.org': 1,
#  'info@btgcommunity.org': 1,
#  'info@buttsfamilyscholarship.org': 1,
#  'info@c2be.org': 1,
#  'info@camp42.org': 2,
#  'info@camperdown.org': 1,
#  'info@cancersurvivorspark.org': 2,
#  'info@carolinaballet.org': 5,
#  'info@catalystsports.org': 7,
#  'info@cdcfoundation.org': 1,
#  'info@cedarburgartmuseum.org': 1,
#  'info@ceef.org': 3,
#  'info@center4success.org': 3,
#  'info@centerpeace.net': 2,
#  'info@centraltexaspigs.org': 3,
#  'info@centraltexasspca.org': 1,
#  'info@chanceforhopefoundation.org': 1,
#  'info@cherishourchildren.org': 2,
#  'info@childcaring.org': 1,
#  'info@children4tomorrow.org': 1,
#  'info@childrenfirstinc.org': 1,
#  'info@chosen.care': 2,
#  'info@chronicdisease.org': 2,
#  'info@citycenterwaco.com': 1,
#  'info@citylabhsfoundation.org': 1,
#  'info@ciudadnueva.org': 2,
#  'info@cleanlakesalliance.org': 8,
#  'info@cohpcc.org': 2,
#  'info@collabforchildren.org': 2,
#  'info@colorfulclosetsama.org': 2,
#  'info@comealiveworld.org': 2,
#  'info@comereducationcampus.org': 1,
#  'info@communityprogress.org': 1,
#  'info@compass.team': 1,
#  'info@coventryreserve.org': 3,
#  'info@cpotx.org': 1,
#  'info@creativeaction.org': 4,
#  'info@creativewaco.org': 3,
#  'info@cseeds.org': 4,
#  'info@ctxcf.org': 1,
#  'info@cuisineforhealing.org': 5,
#  'info@cultivatingfamilies.org': 1,
#  'info@deerassociation.com': 1,
#  'info@detroitphoenixcenter.org': 3,
#  'info@detroitpitcrew.com': 1,
#  'info@detroitsound.org': 4,
#  'info@detroitsportsmedia.com': 1,
#  'info@discoverchild.org': 1,
#  'info@doberman911.org': 1,
#  'info@dpsfdn.org': 1,
#  'info@drmm.org': 1,
#  'info@farmersmarketinstitute.org': 1,
#  'info@flintandgenesee.org': 4,
#  'info@fotp.org': 1,
#  'info@friendsofmac.com': 5,
#  'info@g4gghana.org': 1,
#  'info@gadshillcenter.org': 1,
#  'info@galenacenterforthearts.com': 1,
#  'info@galenaparkterrace.com': 1,
#  'info@gardencenterservices.org': 1,
#  'info@gatewaypets.org': 1,
#  'info@gatewaytolearning.org': 1,
#  'info@gbnchildcare.com': 1,
#  'info@gef34.org': 3,
#  'info@gemschicago.org': 4,
#  'info@genegrawefund.org': 1,
#  'info@generalbakerinstitute.org': 1,
#  'info@geneseoparkdistrict.org': 2,
#  'info@genesishousing.org': 1,
#  'info@genyouthnow.org': 1,
#  'info@geramsboosters.org': 1,
#  'info@gerberhart.org': 1,
#  'info@germanschoolchicago.com': 2,
#  'info@gggministries.com': 5,
#  'info@giftofcarl.org': 2,
#  'info@giftofhope.org': 3,
#  'info@gigisplayhouse.org': 1,
#  'info@girlforward.org': 1,
#  'info@glencoehistory.org': 2,
#  'info@gotrnwil.org': 1,
#  'info@hartforhorses.org': 2,
#  'info@healthyfoodsystems.org': 2,
#  'info@helpourmarriage.org': 3,
#  'info@hialeahcc.org': 1,
#  'info@high5give5.org': 2,
#  'info@highimpacto.org': 1,
#  'info@himalayanyouthfoundation.org': 1,
#  'info@ilraiseyourhand.org': 4,
#  'info@inspiremuncie.org': 2,
#  'info@kazooschool.org': 2,
#  'info@keepgrowingdetroit.org': 2,
#  'info@kydnet.org': 2,
#  'info@loveforstlouis.org': 2,
#  'info@mays.k12.in.us': 1,
#  'info@mediaburn.org': 2,
#  'info@missouriforgetmenot.org': 1,
#  'info@munciemission.org': 1,
#  'info@mygiantsteps.org': 2,
#  'info@mywrc.org': 1,
#  'info@naaaa.com': 1,
#  'info@naccse.org': 1,
#  'info@naehcy.org': 1,
#  'info@naifa.org': 3,
#  'info@nalinikids.org': 2,
#  'info@namcatlanta.org': 1,
#  'info@namierie.org': 1,
#  'info@naminepa.org': 1,
#  'info@namiyorkadams.org': 1,
#  'info@nancyrun.org': 2,
#  'info@naonfoundation.org': 1,
#  'info@ncfgiving.com': 1,
#  'info@neoadulted.org': 2,
#  'info@networkscoop.org': 1,
#  'info@neveralone.org': 3,
#  'info@neverlost.org': 1,
#  'info@newamericanpathways.org': 1,
#  'info@newliferescues.org': 4,
#  'info@newsongmission.org': 1,
#  'info@ngsingers.com': 4,
#  'info@ngyaa.org': 1,
#  'info@nhsfl.org': 1,
#  'info@nwicancerkids.org': 7,
#  'info@oaklawn.org': 1,
#  'info@oroquay.org': 1,
#  'info@ourncm.org': 1,
#  'info@parakleteministries.com': 3,
#  'info@parcainc.org': 1,
#  'info@parkviewcooperativepreschool.com': 1,
#  'info@pasionyarteflamenco.org': 2,
#  'info@passagestorecovery.org': 1,
#  'info@pawsandthink.org': 1,
#  'info@pccse.org': 1,
#  'info@peaceadvocacynetwork.org': 1,
#  'info@peacevalleyholisticcenter.org': 2,
#  'info@pearlsbuck.org': 2,
#  'info@peggybrowningfund.org': 2,
#  'info@peirce.edu': 1,
#  'info@pennac.org': 1,
#  'info@pennmontacademy.com': 1,
#  'info@pilotedindiana.org': 3,
#  'info@pixlapeer.org': 1,
#  'info@polishedpebbles.com': 1,
#  'info@premierarts.org': 2,
#  'info@preservingbibletimes.org': 1,
#  'info@projectgivebacktocommunity.org': 2,
#  'info@projectlucas.org': 4,
#  'info@protectthefaith.org': 1,
#  'info@ptsoccerclub.com': 1,
#  'info@raventheatre.com': 1,
#  'info@raygraham.org': 1,
#  'info@reachindia.org': 1,
#  'info@reallifeprogram.org': 2,
#  'info@rebuildingtogether-aff.org': 1,
#  'info@reconciledworld.org': 1,
#  'info@reestablishrichmond.org': 1,
#  'info@refugeeone.org': 1,
#  'info@refushe.org': 1,
#  'info@replenishfoundation.org': 1,
#  'info@resilience-education.org': 6,
#  'info@resolutionvirginia.org': 2,
#  'info@resourcesofhope.org': 1,
#  'info@ret3.org': 6,
#  'info@revive-international.org': 1,
#  'info@revivfamilysupport.org': 1,
#  'info@reycc.com': 1,
#  'info@rhymeandreason.net': 1,
#  'info@richlandcarrousel.com': 2,
#  'info@richlandcountylandbank.org': 1,
#  'info@ridecincinnati.org': 2,
#  'info@rifnova.org': 2,
#  'info@ripplaffect.org': 1,
#  'info@riseinlovecenter.org': 1,
#  'info@sagemetrodetroit.org': 1,
#  'info@saintaugustineballet.com': 1,
#  'info@santafegirlsschool.org': 1,
#  'info@santafeskiteam.com': 1,
#  'info@santafewineandchile.org': 1,
#  'info@secondandseven.com': 6,
#  'info@sfrailyardcc.org': 1,
#  'info@shareyourcare.com': 1,
#  'info@shuterlibrary.net': 3,
#  'info@sierrahealth.net': 1,
#  'info@sjbhumanesociety.org': 1,
#  'info@sjmsaa.com': 1,
#  'info@sota.org': 1,
#  'info@specialcompass.org': 1,
#  'info@sportxchange.org': 1,
#  'info@springvalleyschool.com': 2,
#  'info@sri-online.org': 1,
#  'info@staaa.org': 1,
#  'info@stjohnsriverkeeper.org': 1,
#  'info@stmichaelschurch.com': 1,
#  'info@storehousenm.org': 3,
#  'info@streetcathub.org': 4,
#  'info@suncountrygolfhouse.com': 1,
#  'info@surfacedesign.org': 3,
#  'info@swnmact.org': 2,
#  'info@swwriters.com': 2,
#  'info@sylviathomascenter.org': 2,
#  'info@talentnomics.org': 1,
#  'info@talkingtalons.org': 1,
#  'info@tallahasseegardenclub.com': 1,
#  'info@tallahasseesymphony.org': 2,
#  'info@teencentralmanheim.org': 5,
#  'info@thebigredbarnretreat.org': 2,
#  'info@thecitadelle.org': 2,
#  'info@thecommunityoffaith.org': 1,
#  'info@thenbec.org': 1,
#  'info@thencpp.org': 3,
#  'info@thepac.center': 1,
#  'info@wheelsofsuccess.org': 2,
#  'info@whisperingmanes.org': 2,
#  'info@wilddolphinproject.org': 1,
#  'info@wilsonhouserecovery.org': 1,
#  'info@wisdomintorah.com': 3,
#  'info@womenscircle.org': 1,
#  'info@womenwin.org': 2,
#  'info@worldaffairscounciljax.org': 1,
#  'info@worldyouthclubs.org': 1,
#  'info@wslr.org': 1,
#  'info@y4c.org': 1,
#  'info@ycc.org': 1,
#  'info@ycoopmail.org': 1,
#  'info@ye2p.org': 2,
#  'info@yeafrog.org': 1,
#  'info@yfainc.org': 1,
#  'info@youngatartmuseum.org': 1,
#  'info@yourgcf.org': 1,
#  'info@youthep.org': 1,
#  'info@youthhavenswfl.org': 1,
#  'info@ywcasouthflorida.org': 1,
#  'inforawldogs@gmail.com': 1,
#  'inforequest@glenwoodacademy.org': 1,
#  'information@cwcf.org': 2,
#  'information@yspb.org': 1,
#  'infowashingtontheater@gmail.com': 7,
#  'james.wheeler@stjohns.k12.fl.us': 3,
#  'janeelliott7@gmail.com': 2,
#  'jean.perog@wilsonsdisease.org': 2,
#  'jennifer.eppolito@stvincent.edu': 1,
#  'jesse@bestillretreats.org': 1,
#  'jlomax@girls4science.org': 2,
#  'jmcconnell@brookland.cc': 1,
#  'joe@aeoutdoors.org': 3,
#  'jon@bridgestones.com': 1,
#  'jpsand@clemson.edu': 1,
#  'jspriet@giannahouse.org': 1,
#  'jsundquist@rampcil.org': 1,
#  'kairkalkaska@gmail.com': 1,
#  'kari.watts@gatewaycr.org': 1,
#  'kathrynweil@susanslegacy.org': 1,
#  'kbkrelief@gmail.com': 2,
#  'kelly@blazeinternational.org': 2,
#  'kelseybrankle@preservemarriages.com': 2,
#  'kevin@appletonice.org': 1,
#  'kevin@wildmesquite.org': 1,
#  'kevink@avenuestocommunity.org': 2,
#  'kgp@kappagammapi.org': 1,
#  'kim@cwi.org': 1,
#  'kk@keithinstitute.org': 1,
#  'kmoulton@taosacademy.org': 1,
#  'ksullivan@fronteragrill.net': 1,
#  'laura@rthome.org': 1,
#  'lisa@brightsideprojectohio.org': 1,
#  'lisa@communityintegrationproject.com': 1,
#  'lmcbride@growthincgeneseo.com': 1,
#  'lnuell@friendsofzb.org': 3,
#  'management@flsteps.org': 3,
#  'manager@highlandsartleague.org': 1,
#  'manager@silvercitygospelmission.org': 1,
#  'marymoss4400@gmail.com': 1,
#  'matthew.mcclinnis@sluhn.org': 1,
#  'mbossman@y2believe.org': 1,
#  'mburr@snmedd.com': 1,
#  'mdantonio@nasd.k12.pa.us': 1,
#  'mdejesus@detroitpal.org': 1,
#  'megand@quanada.org': 1,
#  'members@swaia.org': 1,
#  'membership@searchlightnm.org': 2,
#  'merridith@bbbslowcountry.org': 1,
#  'mferguson@betterlifeins.com': 2,
#  'mgisler@gfwc.org': 3,
#  'mhrbpc@mental-health-recovery.org': 2,
#  'michael@cascadecommunityservices.biz': 1,
#  'michael@saklc.com': 1,
#  'michaelmaloney@gopyouthcenter.org': 1,
#  'michelle.yeater@richlandone.org': 1,
#  'michelle@qcautismcenter.org': 1,
#  'michigancie@gmail.com': 1,
#  'mjmwaits@springsofhopekenya.org': 2,
#  'molly@toponexus.org': 2,
#  'motcwebmail@gmail.com': 2,
#  'mread@detroitchamber.com': 1,
#  'mstevens@ssbrm.com': 1,
#  'nantyglofire@gmail.com': 1,
#  'nape@napequity.org': 1,
#  'narberth.rugbyfc@gmail.com': 1,
#  'nat28newmusic@gmail.com': 2,
#  'natp@natptax.com': 1,
#  'ncarder@brownmemorialhome.com': 1,
#  'ndcchangestartshere@gmail.com': 2,
#  'nemra@nemra.org': 1,
#  'nettie@thebreatheorganization.org': 1,
#  'network@paramountindy.org': 2,
#  'newdawnmin@gmail.com': 1,
#  'newdayschurch91@gmail.com': 2,
#  'news@giftofadoption.org': 1,
#  'ngangwer@centraldetroitchristian.org': 2,
#  'nhans@pc4y.org': 1,
#  'nkfpeers@kidney.org': 1,
#  'noahsarkbbcdc@gmail.com': 3,
#  'nsgc@nsgc.org': 1,
#  'oaklandscemetery@gmail.com': 1,
#  'oaklane@oaklanedaycare.org': 1,
#  'oaklawnwb@gmail.com': 2,
#  'oakmontfd216@gmail.com': 2,
#  'office.stpeteseminary@gmail.com': 1,
#  'office@artsquincy.org': 1,
#  'office@brookhillind.com': 1,
#  'office@camplongridge.com': 3,
#  'office@christianmensnetwork.com': 3,
#  'office@gatewaymontessorischool.org': 1,
#  'office@geographicsociety.org': 2,
#  'office@namimontcopa.org': 6,
#  'office@newgenevaacademy.com': 1,
#  'office@penndel.org': 1,
#  'office@princewilliamacademy.com': 1,
#  'office@rc4cares.com': 4,
#  'office@richmondchristian.com': 1,
#  'office@richmondfriendsschool.org': 1,
#  'office@santafeschool.org': 1,
#  'office@snmstatefairgrounds.net': 1,
#  'office@specialheartsfarm.com': 1,
#  'office@sweetwater-organic.org': 1,
#  'office@theseedofhope.org': 1,
#  'office@wildlifeswfl.org': 1,
#  'oinkingacres@gmail.com': 1,
#  'olqmrc@gmail.com': 1,
#  'orton@bigoakchildcare.org': 3,
#  'ourfathershouse02@gmail.com': 1,
#  'outreach@connemaraconservancy.org': 1,
#  'pampierce@silverbulletproductions.com': 1,
#  'pat@abundantgraceintl.org': 2,
#  'paula@stcloudmainstreet.org': 1,
#  'pawsadoptable@pawsdearborn.org': 2,
#  'pawshancock1@gmail.com': 2,
#  'pawsitivelypom@gmail.com': 1,
#  'pbarnes@youthguidanceprogram.org': 1,
#  'pcashman1965@gmail.com': 1,
#  'peacefulknights@gmail.com': 1,
#  'pearlsserenityhouse@gmail.com': 1,
#  'peersupport@neveralonech.org': 3,
#  'pennarealibrary2001@gmail.com': 1,
#  'pennfoundationquest@sluhn.org': 1,
#  'pennmanorsoccerclub@gmail.com': 1,
#  'penntwpvfd@zoominternet.net': 2,
#  'petinfo@hcflgov.net': 1,
#  'pgreene@tallahasseelenders.org': 1,
#  'phf@phs.org': 1,
#  'pking@npusc.k12.in.us': 2,
#  'pmhg2005@yahoo.com': 1,
#  'pointmanofnewburgh@gmail.com': 1,
#  'ppl@ppl.org': 4,
#  'pr@campchetek.org': 2,
#  'pr@tallahasseemuseum.org': 2,
#  'president.elect@maea.net': 2,
#  'president@castleberryhill.org': 2,
#  'president@clevelandsharks.com': 1,
#  'president@mynct.org': 1,
#  'president@nhsfoundation.org': 2,
#  'president@nsnatl.org': 1,
#  'president@rescueatsea.org': 1,
#  'president@willmclean.com': 2,
#  'programs@readtothem.org': 7,
#  'projectcrossroads@yahoo.com': 2,
#  'projectsuppinc.kg@gmail.com': 1,
#  'prush@axis1.org': 2,
#  'pserve@beloitlibrary.org': 1,
#  'psteinberg@acityforgod.org': 2,
#  'ptfootballboosters@gmail.com': 1,
#  'ptoridgewood@gmail.com': 1,
#  'ptvoces@gmail.com': 2,
#  'pvelempto@gmail.com': 9,
#  'qualityfirstchildcare@gmail.com': 1,
#  'radfordchilddevelopment@gmail.com': 1,
#  'rappcats@rappcats.org': 1,
#  'readersareleadersnonprofit@gmail.com': 1,
#  'recipeforchange@recipeforchangeproject.org': 1,
#  'redoakpto112@gmail.com': 2,
#  'redwingalumni@yahoo.com': 1,
#  'reedcusterjrcomets@gmail.com': 1,
#  'renewrichmondva@gmail.com': 2,
#  'restministries2@gmail.com': 4,
#  'revealedlove@gmail.com': 2,
#  'rfy@reachforyouth.org': 1,
#  'rgrassociation@gmail.com': 3,
#  'rhonda.mcginnis@sparrowacademy.org': 4,
#  'rhonda@ahomeforme.sc': 1,
#  'rhsallsportsboosterclub@yahoo.com': 1,
#  'richardsonsrescue@gmail.com': 1,
#  'richwoodindependentfair@frontier.com': 2,
#  'rick@plateofpeas.com': 1,
#  'ricopetrecovery@yahoo.com': 2,
#  'ridgemontactivitiesboosters@gmail.com': 2,
#  'ridingcentre@gmail.com': 4,
#  'riedelfoundation@gmail.com': 1,
#  'rischall@workwithchrysalis.org': 2,
#  'risnerup@gmail.com': 1,
#  'ritt_jflaker@tccsa.net': 1,
#  'rivercityfarmersmarketmarietta@gmail.com': 1,
#  'rmamusic@comcast.net': 1,
#  'rmcrane58@gmail.com': 1,
#  'robinsnestindypp@gmail.com': 2,
#  'rpost.basicsbeyond@gmail.com': 1,
#  'rsf@reverefoundation.com': 2,
#  'rspringer@ghasems.com': 1,
#  'rudytaylor@food-bank.org': 1,
#  'rushs@iecc.edu': 1,
#  'rvfrd@rvfrd.com': 2,
#  'saber@sabercollege.edu': 2,
#  'sabw@standrewbaywatch.org': 3,
#  'sanctuaryatsoledad@gmail.com': 1,
#  'santafedressage@gmail.com': 1,
#  'santafeskatingclub@gmail.com': 1,
#  'sbeale@carolinachildren.org': 1,
#  'sbhaandsbhp@gmail.com': 5,
#  'sburden@kam.church': 1,
#  'scholarship@svcfoundation.org': 1,
#  'scholarships@nshss.org': 2,
#  'school@childrensworkshopwi.com': 1,
#  'scmsinfo@silvercitymainstreet.com': 1,
#  'service@reanfoundation.org': 3,
#  'serviceheartcasa@gmail.com': 1,
#  'sfarvenice@gmail.com': 3,
#  'sgifiredepartment@gmail.com': 1,
#  'shauselman@rccasi.org': 1,
#  'sing@animasingers.org': 1,
#  'slacoforlando@gmail.com': 1,
#  'slopez@k-connect.org': 3,
#  'smallwonders29603@gmail.com': 1,
#  'smoola@sofwolf.org': 1,
#  'smr@sswmeetings.com': 1,
#  'snmdo@snmdo.org': 1,
#  'social@hgvc.com': 1,
#  'socialmedia@pachvrs.org': 3,
#  'socorrostorehouse@gmail.com': 1,
#  'somos@somosunpueblounido.org': 1,
#  'sonm@sonm.org': 4,
#  'southwestseminar@aol.com': 1,
#  'spacecoastpca@gmail.com': 2,
#  'sparoffice@sparcouncil.org': 1,
#  'spayneuternation@gmail.com': 7,
#  'specialbooksbyspecialkids@gmail.com': 3,
#  'srhester@snmcac.com': 1,
#  'sroy@youngactorstheatre.com': 1,
#  'ss@ssmfi.org': 1,
#  'sscvoc@gmail.com': 1,
#  'sspencer@ywcapbc.org': 3,
#  'stephanie.garrity@rainbows.org': 3,
#  'stevegavers@yahoo.com': 1,
#  'stevekane@spacetec.us': 1,
#  'strongsmartbold@girlsincofchicago.org': 1,
#  'submit@sofl.org': 1,
#  'superhealth12@gmail.com': 1,
#  'support@elchc.org': 1,
#  'support@pmah.org': 1,
#  'support@reformu.com': 4,
#  'support@synergy-group.com.au': 4,
#  'support@wrcfl.org': 1,
#  'susansutliff@sjrstate.edu': 1,
#  'swbcamp@gmail.com': 3,
#  'swharram@geshermi.org': 1,
#  'tallyqbclub@gmail.com': 2,
#  'tanyac@achildshaven.org': 1,
#  'tbpaf1@gmail.com': 1,
#  'tfaulkner@afatherswaysc.org': 2,
#  'thebridgeoftiftareainc@gmail.com': 2,
#  'thenanfoundation@gmail.com': 1,
#  'thewheelofcc@gmail.com': 1,
#  'thrive@cavu.org': 5,
#  'tim.mayer@artistsforthehumanities.org': 1,
#  'timnewcreation517@gmail.com': 1,
#  'timothy@comfortoaksranch.com': 2,
#  'tomjonesleague@gmail.com': 2,
#  'vbaker@sjcds.net': 9,
#  'waycenter@verizon.net': 1,
#  'wheelsfromtheheart100@gmail.com': 2,
#  'whippingchildhoodcancer@gmail.com': 1,
#  'wingsofshelter@aol.com': 2,
#  'wintergardenrotary@gmail.com': 3,
#  'wk@youthspeakoutint.org': 1,
#  'womenoftomorrow@womenoftomorrow.org': 2,
#  'woquin1@galenaparkisd.com': 1,
#  'wordofjoy17@gmail.com': 1,
#  'yborcityrotaryclub@gmail.com': 1,
#  'yesrecyale@gmail.com': 1,
#  'you@spektrum.health': 1,
#  'ywamtampabay@gmail.com': 2,
#  'zetadovefoundation96@gmail.com': 1,
#  'brenda.thrower@tampa.gov': 2,
#  'avemariaacademy@centurytel.net': 1,
#  'brooklynfscohio@gmail.com': 1,
#  'brookofhope@gmail.com': 1,
#  'catkins_wi@yahoo.com': 2,
#  'chaadopt@yahoo.com': 1,
#  'contact@ncbw-metroatlchapter.org': 1,
#  'contact@nhrinc.org': 1,
#  'contactus@brunswickfoodpantry.org': 1,
#  'dan@revada.org': 1,
#  'debra.shuck@ascension.org': 1,
#  'dianegarnetts@gmail.com': 1,
#  'gaylordarts@gaylordarts.org': 1,
#  'gbambulance@hotmail.com': 3,
#  'hailey@cfwjackson.org': 1,
#  'hhhope@verizon.net': 1,
#  'info@besharatgallery.com': 4,
#  'info@blackmanlab.org': 4,
#  'info@bridgingthegapafrica.org': 1,
#  'info@bruknernaturecenter.com': 1,
#  'info@childlegacy.org': 2,
#  'info@coasjc.org': 1,
#  'info@corneroflove.org': 2,
#  'info@greenvilletransmissionclinic.com': 1,
#  'info@hcffcharities.com': 1,
#  'info@kchftv.org': 1,
#  'info@nakashimafoundation.org': 1,
#  'info@ndsccenter.org': 1,
#  'info@nextstepp.org': 1,
#  'info@pathwayindy.org': 1,
#  'info@reachavillage.org': 1,
#  'info@renovateall.org': 1,
#  'info@restorationhousing.org': 4,
#  'info@taliaslegacy.org': 1,
#  'info@teamgear.org': 1,
#  'info@tthfc.org': 2,
#  'jdaffner@mbdcounsel.com': 1,
#  'joincarttoday@gmail.com': 1,
#  'naomisplacewomen@yahoo.com': 1,
#  'office@oakspringcemetery.com': 1,
#  'ohipgh@gmail.com': 2,
#  'palsforpawshc@aol.com': 2,
#  'pennbrad.oilmuseum@yahoo.com': 2,
#  'pp2crescue@gmail.com': 1,
#  'program-manager@tsicnassau.org': 2,
#  'qcpaws@yahoo.com': 1,
#  'redemptanfp@yahoo.com': 1,
#  'rfkbaade@yahoo.com': 1,
#  'rgordon@rmhfoundation.org': 1,
#  'richardsvillefireandrescue@gmail.com': 1,
#  'ridewithvalor@gmail.com': 1,
#  'saturdaymkt@yahoo.com': 1,
#  'sestep2032@aol.com': 2,
#  'statesboroexchangeclub@gmail.com': 1,
#  'wcharles@brightfutureforkids.com': 1,
#  'wi.arvssweb@yahoo.com': 2,
#  'zach@broadleafwriters.com': 1}

# %%
# Sorted the dictionary from highest key value to lowest
sorted_emails = sorted(email_count.items(), key=lambda x: x[1], reverse=True)
sorted_emails
# Out:
# [('info@refed.org', 10),
#  ('pvelempto@gmail.com', 9),
#  ('vbaker@sjcds.net', 9),
#  ('info@nbnfoundation.us', 8),
#  ('info@cleanlakesalliance.org', 8),
#  ('chrt-info@umich.edu', 7),
#  ('info@bookwormgardens.org', 7),
#  ('info@fredgoodwill.org', 7),
#  ('info@galesburgarts.org', 7),
#  ('info@pcacareconnections.org', 7),
#  ('info@rw-c.org', 7),
#  ('social@detroitregionalpartnership.com', 7),
#  ('connect@pantheontheatre.org', 7),
#  ('info@catalystsports.org', 7),
#  ('info@nwicancerkids.org', 7),
#  ('infowashingtontheater@gmail.com', 7),
#  ('programs@readtothem.org', 7),
#  ('spayneuternation@gmail.com', 7),
#  ('foundation@pistons.com', 6),
#  ('info@oberkotterfoundation.org', 6),
#  ('info@rappahannockunitedway.org', 6),
#  ('info@smemnm.org', 6),
#  ('ocof@onecommunityonefamily.org', 6),
#  ('glenellyninfantwelfare@gmail.com', 6),
#  ('info@resilience-education.org', 6),
#  ('info@ret3.org', 6),
#  ('info@secondandseven.com', 6),
#  ('office@namimontcopa.org', 6),
#  ('info@ceri.org', 5),
#  ('meupton@worldpartnerships.org', 5),
#  ('director@quincycatholicschools.org', 5),
#  ('editor@nam-math.org', 5),
#  ('foundation@ysfpb.org', 5),
#  ('groupevents@tottrg.com', 5),
#  ('hhsrowingclub@gmail.com', 5),
#  ('info@carolinaballet.org', 5),
#  ('info@cuisineforhealing.org', 5),
#  ('info@friendsofmac.com', 5),
#  ('info@gggministries.com', 5),
#  ('info@teencentralmanheim.org', 5),
#  ('sbhaandsbhp@gmail.com', 5),
#  ('thrive@cavu.org', 5),
#  ('director@sherishoh.org', 4),
#  ('info@parishresourcecenter.org', 4),
#  ('info@riverrangers.org', 4),
#  ('ahales@communitiesaligned.org', 4),
#  ('angie.mollenkopf@nvm.org', 4),
#  ('anotherchance4animals@gmail.com', 4),
#  ('caffj@chicagoappleseed.org', 4),
#  ('contact@gordoncountychamber.com', 4),
#  ('edenrecoveryhouse@gmail.com', 4),
#  ('gallery510@sbcglobal.net', 4),
#  ('hello@beautifulgatecenter.org', 4),
#  ('hello@neveralonewidows.com', 4),
#  ('info@beloitartcenter.com', 4),
#  ('info@creativeaction.org', 4),
#  ('info@cseeds.org', 4),
#  ('info@detroitsound.org', 4),
#  ('info@flintandgenesee.org', 4),
#  ('info@gemschicago.org', 4),
#  ('info@ilraiseyourhand.org', 4),
#  ('info@newliferescues.org', 4),
#  ('info@ngsingers.com', 4),
#  ('info@projectlucas.org', 4),
#  ('info@streetcathub.org', 4),
#  ('office@rc4cares.com', 4),
#  ('ppl@ppl.org', 4),
#  ('restministries2@gmail.com', 4),
#  ('rhonda.mcginnis@sparrowacademy.org', 4),
#  ('ridingcentre@gmail.com', 4),
#  ('sonm@sonm.org', 4),
#  ('support@reformu.com', 4),
#  ('support@synergy-group.com.au', 4),
#  ('info@besharatgallery.com', 4),
#  ('info@blackmanlab.org', 4),
#  ('info@restorationhousing.org', 4),
#  ('angela@caanderson.org', 3),
#  ('baf@brunswickathleticfoundation.org', 3),
#  ('bowsoffice@beyondourwalls.org', 3),
#  ('brcg.rohingya@gmail.com', 3),
#  ('bridgeofhopeincchicago@gmail.com', 3),
#  ('celticcovecatholic@gmail.com', 3),
#  ('christmasinjulycharitywi@gmail.com', 3),
#  ('coastalbendfb@coastalbendfoodbank.org', 3),
#  ('contact@newchurchesnow.org', 3),
#  ('contact@rhythmx.org', 3),
#  ('dcox@ahla.com', 3),
#  ('dhanimalrescue@gmail.com', 3),
#  ('donate@reachoutcc.org', 3),
#  ('furangelsanimalsanctuary@gmail.com', 3),
#  ('heather@reesestronginc.com', 3),
#  ('info@ceef.org', 3),
#  ('info@center4success.org', 3),
#  ('info@centraltexaspigs.org', 3),
#  ('info@coventryreserve.org', 3),
#  ('info@creativewaco.org', 3),
#  ('info@detroitphoenixcenter.org', 3),
#  ('info@gef34.org', 3),
#  ('info@giftofhope.org', 3),
#  ('info@helpourmarriage.org', 3),
#  ('info@naifa.org', 3),
#  ('info@neveralone.org', 3),
#  ('info@parakleteministries.com', 3),
#  ('info@pilotedindiana.org', 3),
#  ('info@shuterlibrary.net', 3),
#  ('info@storehousenm.org', 3),
#  ('info@surfacedesign.org', 3),
#  ('info@thencpp.org', 3),
#  ('info@wisdomintorah.com', 3),
#  ('james.wheeler@stjohns.k12.fl.us', 3),
#  ('joe@aeoutdoors.org', 3),
#  ('lnuell@friendsofzb.org', 3),
#  ('management@flsteps.org', 3),
#  ('mgisler@gfwc.org', 3),
#  ('noahsarkbbcdc@gmail.com', 3),
#  ('office@camplongridge.com', 3),
#  ('office@christianmensnetwork.com', 3),
#  ('orton@bigoakchildcare.org', 3),
#  ('peersupport@neveralonech.org', 3),
#  ('rgrassociation@gmail.com', 3),
#  ('sabw@standrewbaywatch.org', 3),
#  ('service@reanfoundation.org', 3),
#  ('sfarvenice@gmail.com', 3),
#  ('slopez@k-connect.org', 3),
#  ('socialmedia@pachvrs.org', 3),
#  ('specialbooksbyspecialkids@gmail.com', 3),
#  ('sspencer@ywcapbc.org', 3),
#  ('stephanie.garrity@rainbows.org', 3),
#  ('swbcamp@gmail.com', 3),
#  ('wintergardenrotary@gmail.com', 3),
#  ('gbambulance@hotmail.com', 3),
#  ('75kambly@gmail.com', 2),
#  ('abbysfriends@homesc.com', 2),
#  ('ashleysangelsinc@gmail.com', 2),
#  ('assoc.manager@nacdep.net', 2),
#  ('bcumchurch@gmail.com', 2),
#  ('berniolson@rappbenfund.org', 2),
#  ('blackpearltn2018@gmail.com', 2),
#  ('blair@rangermemorial.org', 2),
#  ('bon@billgrahamfoundation.org', 2),
#  ('boxoffice@santafeplayhouse.org', 2),
#  ('brianasheartofgold@gmail.com', 2),
#  ('brownbagfoodproject@gmail.com', 2),
#  ('buildalegacyinc@gmail.com', 2),
#  ('cafabecky@gmail.com', 2),
#  ('camaga.atlanta@gmail.com', 2),
#  ('camp@campquest.org', 2),
#  ('capntally@gmail.com', 2),
#  ('caringhearts@thriftshop.network', 2),
#  ('casipets@sbcglobal.net', 2),
#  ('catalystclc1@gmail.com', 2),
#  ('cedarrapids@countryhouse.net', 2),
#  ('chc@centex.net', 2),
#  ('cmc@centralmichigancare.com', 2),
#  ('cnaparalla@waupacaschools.org', 2),
#  ('communications@bufordcityschools.org', 2),
#  ('contact@arisemke.org', 2),
#  ('contact@chestnutarts.org', 2),
#  ('contact@givenkind.org', 2),
#  ('contact@pmaaems.org', 2),
#  ('contact@synapticsparks.org', 2),
#  ('contactus@bellagail.org', 2),
#  ('cover6outdoors@gmail.com', 2),
#  ('cstkinformation@gmail.com', 2),
#  ('dave@r3development.org', 2),
#  ('david@bisfoundation.net', 2),
#  ('development@cathedral-center.org', 2),
#  ('development@cbrrescue.org', 2),
#  ('director@cctaonline.org', 2),
#  ('director@locker505.org', 2),
#  ('dist12@ptd.net', 2),
#  ('donations@garfieldpark.org', 2),
#  ('fiestaparades@gmail.com', 2),
#  ('foundation@rbha.org', 2),
#  ('fredgreen@hpnfc.org', 2),
#  ('frontdesk@restonchildrenscenter.org', 2),
#  ('galesburgrotary@gmail.com', 2),
#  ('general-info@roottrj.org', 2),
#  ('geneseoeducation1@gmail.com', 2),
#  ('gjohnson@benedictcenter.org', 2),
#  ('glencoeptocentral@gmail.com', 2),
#  ('gplfoundation1930@gmail.com', 2),
#  ('hello@pennair.com', 2),
#  ('info@bdlia.org', 2),
#  ('info@belovedatlanta.org', 2),
#  ('info@beth-el.org', 2),
#  ('info@bridgingtheway.org', 2),
#  ('info@camp42.org', 2),
#  ('info@cancersurvivorspark.org', 2),
#  ('info@centerpeace.net', 2),
#  ('info@cherishourchildren.org', 2),
#  ('info@chosen.care', 2),
#  ('info@chronicdisease.org', 2),
#  ('info@ciudadnueva.org', 2),
#  ('info@cohpcc.org', 2),
#  ('info@collabforchildren.org', 2),
#  ('info@colorfulclosetsama.org', 2),
#  ('info@comealiveworld.org', 2),
#  ('info@geneseoparkdistrict.org', 2),
#  ('info@germanschoolchicago.com', 2),
#  ('info@giftofcarl.org', 2),
#  ('info@glencoehistory.org', 2),
#  ('info@hartforhorses.org', 2),
#  ('info@healthyfoodsystems.org', 2),
#  ('info@high5give5.org', 2),
#  ('info@inspiremuncie.org', 2),
#  ('info@kazooschool.org', 2),
#  ('info@keepgrowingdetroit.org', 2),
#  ('info@kydnet.org', 2),
#  ('info@loveforstlouis.org', 2),
#  ('info@mediaburn.org', 2),
#  ('info@mygiantsteps.org', 2),
#  ('info@nalinikids.org', 2),
#  ('info@nancyrun.org', 2),
#  ('info@neoadulted.org', 2),
#  ('info@pasionyarteflamenco.org', 2),
#  ('info@peacevalleyholisticcenter.org', 2),
#  ('info@pearlsbuck.org', 2),
#  ('info@peggybrowningfund.org', 2),
#  ('info@premierarts.org', 2),
#  ('info@projectgivebacktocommunity.org', 2),
#  ('info@reallifeprogram.org', 2),
#  ('info@resolutionvirginia.org', 2),
#  ('info@richlandcarrousel.com', 2),
#  ('info@ridecincinnati.org', 2),
#  ('info@rifnova.org', 2),
#  ('info@springvalleyschool.com', 2),
#  ('info@swnmact.org', 2),
#  ('info@swwriters.com', 2),
#  ('info@sylviathomascenter.org', 2),
#  ('info@tallahasseesymphony.org', 2),
#  ('info@thebigredbarnretreat.org', 2),
#  ('info@thecitadelle.org', 2),
#  ('info@wheelsofsuccess.org', 2),
#  ('info@whisperingmanes.org', 2),
#  ('info@womenwin.org', 2),
#  ('info@ye2p.org', 2),
#  ('information@cwcf.org', 2),
#  ('janeelliott7@gmail.com', 2),
#  ('jean.perog@wilsonsdisease.org', 2),
#  ('jlomax@girls4science.org', 2),
#  ('kbkrelief@gmail.com', 2),
#  ('kelly@blazeinternational.org', 2),
#  ('kelseybrankle@preservemarriages.com', 2),
#  ('kevink@avenuestocommunity.org', 2),
#  ('membership@searchlightnm.org', 2),
#  ('mferguson@betterlifeins.com', 2),
#  ('mhrbpc@mental-health-recovery.org', 2),
#  ('mjmwaits@springsofhopekenya.org', 2),
#  ('molly@toponexus.org', 2),
#  ('motcwebmail@gmail.com', 2),
#  ('nat28newmusic@gmail.com', 2),
#  ('ndcchangestartshere@gmail.com', 2),
#  ('network@paramountindy.org', 2),
#  ('newdayschurch91@gmail.com', 2),
#  ('ngangwer@centraldetroitchristian.org', 2),
#  ('oaklawnwb@gmail.com', 2),
#  ('oakmontfd216@gmail.com', 2),
#  ('office@geographicsociety.org', 2),
#  ('pat@abundantgraceintl.org', 2),
#  ('pawsadoptable@pawsdearborn.org', 2),
#  ('pawshancock1@gmail.com', 2),
#  ('penntwpvfd@zoominternet.net', 2),
#  ('pking@npusc.k12.in.us', 2),
#  ('pr@campchetek.org', 2),
#  ('pr@tallahasseemuseum.org', 2),
#  ('president.elect@maea.net', 2),
#  ('president@castleberryhill.org', 2),
#  ('president@nhsfoundation.org', 2),
#  ('president@willmclean.com', 2),
#  ('projectcrossroads@yahoo.com', 2),
#  ('prush@axis1.org', 2),
#  ('psteinberg@acityforgod.org', 2),
#  ('ptvoces@gmail.com', 2),
#  ('redoakpto112@gmail.com', 2),
#  ('renewrichmondva@gmail.com', 2),
#  ('revealedlove@gmail.com', 2),
#  ('richwoodindependentfair@frontier.com', 2),
#  ('ricopetrecovery@yahoo.com', 2),
#  ('ridgemontactivitiesboosters@gmail.com', 2),
#  ('rischall@workwithchrysalis.org', 2),
#  ('robinsnestindypp@gmail.com', 2),
#  ('rsf@reverefoundation.com', 2),
#  ('rvfrd@rvfrd.com', 2),
#  ('saber@sabercollege.edu', 2),
#  ('scholarships@nshss.org', 2),
#  ('spacecoastpca@gmail.com', 2),
#  ('tallyqbclub@gmail.com', 2),
#  ('tfaulkner@afatherswaysc.org', 2),
#  ('thebridgeoftiftareainc@gmail.com', 2),
#  ('timothy@comfortoaksranch.com', 2),
#  ('tomjonesleague@gmail.com', 2),
#  ('wheelsfromtheheart100@gmail.com', 2),
#  ('wingsofshelter@aol.com', 2),
#  ('womenoftomorrow@womenoftomorrow.org', 2),
#  ('ywamtampabay@gmail.com', 2),
#  ('brenda.thrower@tampa.gov', 2),
#  ('catkins_wi@yahoo.com', 2),
#  ('info@childlegacy.org', 2),
#  ('info@corneroflove.org', 2),
#  ('info@tthfc.org', 2),
#  ('ohipgh@gmail.com', 2),
#  ('palsforpawshc@aol.com', 2),
#  ('pennbrad.oilmuseum@yahoo.com', 2),
#  ('program-manager@tsicnassau.org', 2),
#  ('sestep2032@aol.com', 2),
#  ('wi.arvssweb@yahoo.com', 2),
#  ('1860farm@gmail.com', 1),
#  ('304gaf@gmail.com', 1),
#  ('67help@co.genesee.mi.us', 1),
#  ('admack@gibbesmuseum.org', 1),
#  ('admissions@berry.edu', 1),
#  ('adopt@ctdr.org', 1),
#  ('adriann_young@nobl.k12.in.us', 1),
#  ('ads@baptistcourier.com', 1),
#  ('advancement@cmich.edu', 1),
#  ('advancement@hillelacademytampa.com', 1),
#  ('ahpd_info@ahpd.org', 1),
#  ('alecbrown55@gmail.com', 1),
#  ('amiller@bryanareafoundation.org', 1),
#  ('andrew@abbevillecountyhistoricalsociety.org', 1),
#  ('applications@gsrescue1.org', 1),
#  ('aserna@cityonahillmilwaukee.org', 1),
#  ('ashlyn@firstteescw.org', 1),
#  ('ashwaubenoncooppreschool@gmail.com', 1),
#  ('askus@wnpl.info', 1),
#  ('biblefree@yahoo.com', 1),
#  ('birdies4breastcancercare@gmail.com', 1),
#  ('borntoreadec@gmail.com', 1),
#  ('boscobeledfoundation@gmail.com', 1),
#  ('brightsideyouthranch@gmail.com', 1),
#  ('brokengroundschurch@gmail.com', 1),
#  ('brownhelmhistory@gmail.com', 1),
#  ('brunswickeducationfoundation@gmail.com', 1),
#  ('bullymenotfoundation@gmail.com', 1),
#  ('burgundy.hill@1qct.org', 1),
#  ('camp.jewell@ghymca.org', 1),
#  ('campadamfisher@gmail.com', 1),
#  ('captsampat@embarqmail.com', 1),
#  ('catherinejonesministries@gmail.com', 1),
#  ('ccritchlow@rrlcschool.org', 1),
#  ('cdanforth@capricommunities.com', 1),
#  ('cdcc2011@gmail.com', 1),
#  ('centralgeorgiaautism@gmail.com', 1),
#  ('centroaztlan@sbcglobal.net', 1),
#  ('ceo@afathersplace.org', 1),
#  ('ceo@freedomfoundation.com', 1),
#  ('chambleecopnstuff@gmail.com', 1),
#  ('chief38@comcast.net', 1),
#  ('childsafe@childsafe-sa.org', 1),
#  ('christine@shevlinfamilyfoundation.org', 1),
#  ('cindy@camphappydays.com', 1),
#  ('cleburnefca@gmail.com', 1),
#  ('clientservices@suwanneeec.net', 1),
#  ('cmcgee@familycenters.org', 1),
#  ('cmsa@cmsa.org', 1),
#  ('cocohoustonnow@gmail.com', 1),
#  ('communications@nhnga.org', 1),
#  ('communications@stah.org', 1),
#  ('communications@swancitysc.com', 1),
#  ('communications@tsc.fl.edu', 1),
#  ('communityforchildren@gmail.com', 1),
#  ('connect@geccf.org', 1),
#  ('contact@benjacksonfoundation.org', 1),
#  ('contact@beyondabuse.info', 1),
#  ('contact@creativedoc.org', 1),
#  ('contact@furagoodpaws.org', 1),
#  ('contact@historyandnature.org', 1),
#  ('contact@kgsymphony.org', 1),
#  ('contact@oakmanor.org', 1),
#  ('contact@pennmanoredfoundation.org', 1),
#  ('contact@risingstarlearningcenter.com', 1),
#  ('contact@scmrcd.org', 1),
#  ('contact@supportnef.org', 1),
#  ('contact@thepeacemakercenter.org', 1),
#  ('contact@yminstitute.com', 1),
#  ('contactus@qcdc.org', 1),
#  ('corp@blackpush.org', 1),
#  ('crosscreekmeadows@gmail.com', 1),
#  ('crossthreadsthrift@gmail.com', 1),
#  ('ctritch@newhavencarecenter.org', 1),
#  ('cullinanparkconservancy@gmail.com', 1),
#  ('curator@kelsohouse.org', 1),
#  ('cure.local@gmail.com', 1),
#  ('customerservice@rsna.org', 1),
#  ('cwalterhouse@sb.school', 1),
#  ('dames@nscda.org', 1),
#  ('dave@cowboyshelpingcowboys.com', 1),
#  ('derekc@chileda.org', 1),
#  ('development@detroitpal.org', 1),
#  ('development@girlsinthegame.org', 1),
#  ('dgorski@caritas.us', 1),
#  ('dhoughton@wildlandscapes.org', 1),
#  ('dhwegener.ntca@gmail.com', 1),
#  ('dir@nccs-inc.org', 1),
#  ('director@boltonrefuge.org', 1),
#  ('director@campk.net', 1),
#  ('director@glencoeyouthservices.org', 1),
#  ('director@globalallianceafrica.org', 1),
#  ('drkfitz52@gmail.com', 1),
#  ('dsingh@pediamanor.org', 1),
#  ('ellen@beloitmealsonwheels.org', 1),
#  ('email@santafe.edu', 1),
#  ('equity.officer@sfcollege.edu', 1),
#  ('erika@corazonsa.org', 1),
#  ('evonn@zoeloren.org', 1),
#  ('exec@blackpine.org', 1),
#  ('exec@wpdaynursery.org', 1),
#  ('executivedirector@geyfcs.org', 1),
#  ('fleenor@nomadchurch.org', 1),
#  ('foundation@gailborden.info', 1),
#  ('foundation@hccfl.edu', 1),
#  ('foundation@wil-power.org', 1),
#  ('fredakalinateam@gmail.com', 1),
#  ('frontdesk@readcenter.org', 1),
#  ('frontdesk@richlandacademy.com', 1),
#  ('futures@futuresunlimited.org', 1),
#  ('galenafd@sbcglobal.net', 1),
#  ('garridostrayrescue@gmail.com', 1),
#  ('gates.vols@gmail.com', 1),
#  ('gaylordhighschoolhockey@gmail.com', 1),
#  ('gbnbooster@gmail.com', 1),
#  ('gcfmc@comcast.net', 1),
#  ('gcouncilchicago@gmail.com', 1),
#  ('gcs@geneseechristianschool.com', 1),
#  ('gdarling@daytonfoundation.org', 1),
#  ('geethamandalam1978@gmail.com', 1),
#  ('generoushands24@gmail.com', 1),
#  ('geneseecountyhistoricalsociety@gmail.com', 1),
#  ('geneseetownship@geneseetwpmi.gov', 1),
#  ('geneseopantry@gmail.com', 1),
#  ('genesisoutreachministriesintl@gmail.com', 1),
#  ('genevafoundation@presbyterianhomes.org', 1),
#  ('george@swop.net', 1),
#  ('getinfo@genesisschools.org', 1),
#  ('gibbsl@capetigers.com', 1),
#  ('gibsonton.elementary@hcps.net', 1),
#  ('givingdupage@dupagecounty.gov', 1),
#  ('gjones@skyymca.org', 1),
#  ('glenellynrotary@gmail.com', 1),
#  ('glenhagenfarm@gmail.com', 1),
#  ('globalaction@globalaction.com', 1),
#  ('gmsnorthpto@gmail.com', 1),
#  ('grants@gamechangers.film', 1),
#  ('grants@santafefilminstitute.org', 1),
#  ('hbpublicrecords@highlandbeach.us', 1),
#  ('hces@stjohns.k12.fl.us', 1),
#  ('hcfrpublicrelations@hcfl.gov', 1),
#  ('hello@odcenter.org', 1),
#  ('hello@thecovewaco.org', 1),
#  ('help@countyhealthplans.org', 1),
#  ('help@nationalinfantryfoundation.org', 1),
#  ('help@nbmbaa.org', 1),
#  ('highlands4h@ifas.ufl.edu', 1),
#  ('historyrhs@gmail.com', 1),
#  ('hophampton@gmail.com', 1),
#  ('hpgcc@hpgcc.com', 1),
#  ('iieresearch@iie.org', 1),
#  ('imamadly1@yahoo.com', 1),
#  ('info.nsasavannah@gmail.com', 1),
#  ('info@1049theriver.com', 1),
#  ('info@acabroadway.com', 1),
#  ('info@amazed15.org', 1),
#  ('info@arborplaceinc.org', 1),
#  ('info@arc-southeast.org', 1),
#  ('info@becauseofkennedy.org', 1),
#  ('info@becauseonematters.org', 1),
#  ('info@benjamins-house.org', 1),
#  ('info@bestower.org', 1),
#  ('info@blackcreek-cc.com', 1),
#  ('info@blackrosefoundation.org', 1),
#  ('info@blackvotersmatterfund.org', 1),
#  ('info@blessingsworkingtogether.org', 1),
#  ('info@blueribbonschools.com', 1),
#  ('info@brightontheirworld.org', 1),
#  ('info@brigidspath.org', 1),
#  ('info@brokenchainsministry.org', 1),
#  ('info@brookhavencommerce.org', 1),
#  ('info@btgcommunity.org', 1),
#  ('info@buttsfamilyscholarship.org', 1),
#  ('info@c2be.org', 1),
#  ('info@camperdown.org', 1),
#  ('info@cdcfoundation.org', 1),
#  ('info@cedarburgartmuseum.org', 1),
#  ('info@centraltexasspca.org', 1),
#  ('info@chanceforhopefoundation.org', 1),
#  ('info@childcaring.org', 1),
#  ('info@children4tomorrow.org', 1),
#  ('info@childrenfirstinc.org', 1),
#  ('info@citycenterwaco.com', 1),
#  ('info@citylabhsfoundation.org', 1),
#  ('info@comereducationcampus.org', 1),
#  ('info@communityprogress.org', 1),
#  ('info@compass.team', 1),
#  ('info@cpotx.org', 1),
#  ('info@ctxcf.org', 1),
#  ('info@cultivatingfamilies.org', 1),
#  ('info@deerassociation.com', 1),
#  ('info@detroitpitcrew.com', 1),
#  ('info@detroitsportsmedia.com', 1),
#  ('info@discoverchild.org', 1),
#  ('info@doberman911.org', 1),
#  ('info@dpsfdn.org', 1),
#  ('info@drmm.org', 1),
#  ('info@farmersmarketinstitute.org', 1),
#  ('info@fotp.org', 1),
#  ('info@g4gghana.org', 1),
#  ('info@gadshillcenter.org', 1),
#  ('info@galenacenterforthearts.com', 1),
#  ('info@galenaparkterrace.com', 1),
#  ('info@gardencenterservices.org', 1),
#  ('info@gatewaypets.org', 1),
#  ('info@gatewaytolearning.org', 1),
#  ('info@gbnchildcare.com', 1),
#  ('info@genegrawefund.org', 1),
#  ('info@generalbakerinstitute.org', 1),
#  ('info@genesishousing.org', 1),
#  ('info@genyouthnow.org', 1),
#  ('info@geramsboosters.org', 1),
#  ('info@gerberhart.org', 1),
#  ('info@gigisplayhouse.org', 1),
#  ('info@girlforward.org', 1),
#  ('info@gotrnwil.org', 1),
#  ('info@hialeahcc.org', 1),
#  ('info@highimpacto.org', 1),
#  ('info@himalayanyouthfoundation.org', 1),
#  ('info@mays.k12.in.us', 1),
#  ('info@missouriforgetmenot.org', 1),
#  ('info@munciemission.org', 1),
#  ('info@mywrc.org', 1),
#  ('info@naaaa.com', 1),
#  ('info@naccse.org', 1),
#  ('info@naehcy.org', 1),
#  ('info@namcatlanta.org', 1),
#  ('info@namierie.org', 1),
#  ('info@naminepa.org', 1),
#  ('info@namiyorkadams.org', 1),
#  ('info@naonfoundation.org', 1),
#  ('info@ncfgiving.com', 1),
#  ('info@networkscoop.org', 1),
#  ('info@neverlost.org', 1),
#  ('info@newamericanpathways.org', 1),
#  ('info@newsongmission.org', 1),
#  ('info@ngyaa.org', 1),
#  ('info@nhsfl.org', 1),
#  ('info@oaklawn.org', 1),
#  ('info@oroquay.org', 1),
#  ('info@ourncm.org', 1),
#  ('info@parcainc.org', 1),
#  ('info@parkviewcooperativepreschool.com', 1),
#  ('info@passagestorecovery.org', 1),
#  ('info@pawsandthink.org', 1),
#  ('info@pccse.org', 1),
#  ('info@peaceadvocacynetwork.org', 1),
#  ('info@peirce.edu', 1),
#  ('info@pennac.org', 1),
#  ('info@pennmontacademy.com', 1),
#  ('info@pixlapeer.org', 1),
#  ('info@polishedpebbles.com', 1),
#  ('info@preservingbibletimes.org', 1),
#  ('info@protectthefaith.org', 1),
#  ('info@ptsoccerclub.com', 1),
#  ('info@raventheatre.com', 1),
#  ('info@raygraham.org', 1),
#  ('info@reachindia.org', 1),
#  ('info@rebuildingtogether-aff.org', 1),
#  ('info@reconciledworld.org', 1),
#  ('info@reestablishrichmond.org', 1),
#  ('info@refugeeone.org', 1),
#  ('info@refushe.org', 1),
#  ('info@replenishfoundation.org', 1),
#  ('info@resourcesofhope.org', 1),
#  ('info@revive-international.org', 1),
#  ('info@revivfamilysupport.org', 1),
#  ('info@reycc.com', 1),
#  ('info@rhymeandreason.net', 1),
#  ('info@richlandcountylandbank.org', 1),
#  ('info@ripplaffect.org', 1),
#  ('info@riseinlovecenter.org', 1),
#  ('info@sagemetrodetroit.org', 1),
#  ('info@saintaugustineballet.com', 1),
#  ('info@santafegirlsschool.org', 1),
#  ('info@santafeskiteam.com', 1),
#  ('info@santafewineandchile.org', 1),
#  ('info@sfrailyardcc.org', 1),
#  ('info@shareyourcare.com', 1),
#  ('info@sierrahealth.net', 1),
#  ('info@sjbhumanesociety.org', 1),
#  ('info@sjmsaa.com', 1),
#  ('info@sota.org', 1),
#  ('info@specialcompass.org', 1),
#  ('info@sportxchange.org', 1),
#  ('info@sri-online.org', 1),
#  ('info@staaa.org', 1),
#  ('info@stjohnsriverkeeper.org', 1),
#  ('info@stmichaelschurch.com', 1),
#  ('info@suncountrygolfhouse.com', 1),
#  ('info@talentnomics.org', 1),
#  ('info@talkingtalons.org', 1),
#  ('info@tallahasseegardenclub.com', 1),
#  ('info@thecommunityoffaith.org', 1),
#  ('info@thenbec.org', 1),
#  ('info@thepac.center', 1),
#  ('info@wilddolphinproject.org', 1),
#  ('info@wilsonhouserecovery.org', 1),
#  ('info@womenscircle.org', 1),
#  ('info@worldaffairscounciljax.org', 1),
#  ('info@worldyouthclubs.org', 1),
#  ('info@wslr.org', 1),
#  ('info@y4c.org', 1),
#  ('info@ycc.org', 1),
#  ('info@ycoopmail.org', 1),
#  ('info@yeafrog.org', 1),
#  ('info@yfainc.org', 1),
#  ('info@youngatartmuseum.org', 1),
#  ('info@yourgcf.org', 1),
#  ('info@youthep.org', 1),
#  ('info@youthhavenswfl.org', 1),
#  ('info@ywcasouthflorida.org', 1),
#  ('inforawldogs@gmail.com', 1),
#  ('inforequest@glenwoodacademy.org', 1),
#  ('information@yspb.org', 1),
#  ('jennifer.eppolito@stvincent.edu', 1),
#  ('jesse@bestillretreats.org', 1),
#  ('jmcconnell@brookland.cc', 1),
#  ('jon@bridgestones.com', 1),
#  ('jpsand@clemson.edu', 1),
#  ('jspriet@giannahouse.org', 1),
#  ('jsundquist@rampcil.org', 1),
#  ('kairkalkaska@gmail.com', 1),
#  ('kari.watts@gatewaycr.org', 1),
#  ('kathrynweil@susanslegacy.org', 1),
#  ('kevin@appletonice.org', 1),
#  ('kevin@wildmesquite.org', 1),
#  ('kgp@kappagammapi.org', 1),
#  ('kim@cwi.org', 1),
#  ('kk@keithinstitute.org', 1),
#  ('kmoulton@taosacademy.org', 1),
#  ('ksullivan@fronteragrill.net', 1),
#  ('laura@rthome.org', 1),
#  ('lisa@brightsideprojectohio.org', 1),
#  ('lisa@communityintegrationproject.com', 1),
#  ('lmcbride@growthincgeneseo.com', 1),
#  ('manager@highlandsartleague.org', 1),
#  ('manager@silvercitygospelmission.org', 1),
#  ('marymoss4400@gmail.com', 1),
#  ('matthew.mcclinnis@sluhn.org', 1),
#  ('mbossman@y2believe.org', 1),
#  ('mburr@snmedd.com', 1),
#  ('mdantonio@nasd.k12.pa.us', 1),
#  ('mdejesus@detroitpal.org', 1),
#  ('megand@quanada.org', 1),
#  ('members@swaia.org', 1),
#  ('merridith@bbbslowcountry.org', 1),
#  ('michael@cascadecommunityservices.biz', 1),
#  ('michael@saklc.com', 1),
#  ('michaelmaloney@gopyouthcenter.org', 1),
#  ('michelle.yeater@richlandone.org', 1),
#  ('michelle@qcautismcenter.org', 1),
#  ('michigancie@gmail.com', 1),
#  ('mread@detroitchamber.com', 1),
#  ('mstevens@ssbrm.com', 1),
#  ('nantyglofire@gmail.com', 1),
#  ('nape@napequity.org', 1),
#  ('narberth.rugbyfc@gmail.com', 1),
#  ('natp@natptax.com', 1),
#  ('ncarder@brownmemorialhome.com', 1),
#  ('nemra@nemra.org', 1),
#  ('nettie@thebreatheorganization.org', 1),
#  ('newdawnmin@gmail.com', 1),
#  ('news@giftofadoption.org', 1),
#  ('nhans@pc4y.org', 1),
#  ('nkfpeers@kidney.org', 1),
#  ('nsgc@nsgc.org', 1),
#  ('oaklandscemetery@gmail.com', 1),
#  ('oaklane@oaklanedaycare.org', 1),
#  ('office.stpeteseminary@gmail.com', 1),
#  ('office@artsquincy.org', 1),
#  ('office@brookhillind.com', 1),
#  ('office@gatewaymontessorischool.org', 1),
#  ('office@newgenevaacademy.com', 1),
#  ('office@penndel.org', 1),
#  ('office@princewilliamacademy.com', 1),
#  ('office@richmondchristian.com', 1),
#  ('office@richmondfriendsschool.org', 1),
#  ('office@santafeschool.org', 1),
#  ('office@snmstatefairgrounds.net', 1),
#  ('office@specialheartsfarm.com', 1),
#  ('office@sweetwater-organic.org', 1),
#  ('office@theseedofhope.org', 1),
#  ('office@wildlifeswfl.org', 1),
#  ('oinkingacres@gmail.com', 1),
#  ('olqmrc@gmail.com', 1),
#  ('ourfathershouse02@gmail.com', 1),
#  ('outreach@connemaraconservancy.org', 1),
#  ('pampierce@silverbulletproductions.com', 1),
#  ('paula@stcloudmainstreet.org', 1),
#  ('pawsitivelypom@gmail.com', 1),
#  ('pbarnes@youthguidanceprogram.org', 1),
#  ('pcashman1965@gmail.com', 1),
#  ('peacefulknights@gmail.com', 1),
#  ('pearlsserenityhouse@gmail.com', 1),
#  ('pennarealibrary2001@gmail.com', 1),
#  ('pennfoundationquest@sluhn.org', 1),
#  ('pennmanorsoccerclub@gmail.com', 1),
#  ('petinfo@hcflgov.net', 1),
#  ('pgreene@tallahasseelenders.org', 1),
#  ('phf@phs.org', 1),
#  ('pmhg2005@yahoo.com', 1),
#  ('pointmanofnewburgh@gmail.com', 1),
#  ('president@clevelandsharks.com', 1),
#  ('president@mynct.org', 1),
#  ('president@nsnatl.org', 1),
#  ('president@rescueatsea.org', 1),
#  ('projectsuppinc.kg@gmail.com', 1),
#  ('pserve@beloitlibrary.org', 1),
#  ('ptfootballboosters@gmail.com', 1),
#  ('ptoridgewood@gmail.com', 1),
#  ('qualityfirstchildcare@gmail.com', 1),
#  ('radfordchilddevelopment@gmail.com', 1),
#  ('rappcats@rappcats.org', 1),
#  ('readersareleadersnonprofit@gmail.com', 1),
#  ('recipeforchange@recipeforchangeproject.org', 1),
#  ('redwingalumni@yahoo.com', 1),
#  ('reedcusterjrcomets@gmail.com', 1),
#  ('rfy@reachforyouth.org', 1),
#  ('rhonda@ahomeforme.sc', 1),
#  ('rhsallsportsboosterclub@yahoo.com', 1),
#  ('richardsonsrescue@gmail.com', 1),
#  ('rick@plateofpeas.com', 1),
#  ('riedelfoundation@gmail.com', 1),
#  ('risnerup@gmail.com', 1),
#  ('ritt_jflaker@tccsa.net', 1),
#  ('rivercityfarmersmarketmarietta@gmail.com', 1),
#  ('rmamusic@comcast.net', 1),
#  ('rmcrane58@gmail.com', 1),
#  ('rpost.basicsbeyond@gmail.com', 1),
#  ('rspringer@ghasems.com', 1),
#  ('rudytaylor@food-bank.org', 1),
#  ('rushs@iecc.edu', 1),
#  ('sanctuaryatsoledad@gmail.com', 1),
#  ('santafedressage@gmail.com', 1),
#  ('santafeskatingclub@gmail.com', 1),
#  ('sbeale@carolinachildren.org', 1),
#  ('sburden@kam.church', 1),
#  ('scholarship@svcfoundation.org', 1),
#  ('school@childrensworkshopwi.com', 1),
#  ('scmsinfo@silvercitymainstreet.com', 1),
#  ('serviceheartcasa@gmail.com', 1),
#  ('sgifiredepartment@gmail.com', 1),
#  ('shauselman@rccasi.org', 1),
#  ('sing@animasingers.org', 1),
#  ('slacoforlando@gmail.com', 1),
#  ('smallwonders29603@gmail.com', 1),
#  ('smoola@sofwolf.org', 1),
#  ('smr@sswmeetings.com', 1),
#  ('snmdo@snmdo.org', 1),
#  ('social@hgvc.com', 1),
#  ('socorrostorehouse@gmail.com', 1),
#  ('somos@somosunpueblounido.org', 1),
#  ('southwestseminar@aol.com', 1),
#  ('sparoffice@sparcouncil.org', 1),
#  ('srhester@snmcac.com', 1),
#  ('sroy@youngactorstheatre.com', 1),
#  ('ss@ssmfi.org', 1),
#  ('sscvoc@gmail.com', 1),
#  ('stevegavers@yahoo.com', 1),
#  ('stevekane@spacetec.us', 1),
#  ('strongsmartbold@girlsincofchicago.org', 1),
#  ('submit@sofl.org', 1),
#  ('superhealth12@gmail.com', 1),
#  ('support@elchc.org', 1),
#  ('support@pmah.org', 1),
#  ('support@wrcfl.org', 1),
#  ('susansutliff@sjrstate.edu', 1),
#  ('swharram@geshermi.org', 1),
#  ('tanyac@achildshaven.org', 1),
#  ('tbpaf1@gmail.com', 1),
#  ('thenanfoundation@gmail.com', 1),
#  ('thewheelofcc@gmail.com', 1),
#  ('tim.mayer@artistsforthehumanities.org', 1),
#  ('timnewcreation517@gmail.com', 1),
#  ('waycenter@verizon.net', 1),
#  ('whippingchildhoodcancer@gmail.com', 1),
#  ('wk@youthspeakoutint.org', 1),
#  ('woquin1@galenaparkisd.com', 1),
#  ('wordofjoy17@gmail.com', 1),
#  ('yborcityrotaryclub@gmail.com', 1),
#  ('yesrecyale@gmail.com', 1),
#  ('you@spektrum.health', 1),
#  ('zetadovefoundation96@gmail.com', 1),
#  ('avemariaacademy@centurytel.net', 1),
#  ('brooklynfscohio@gmail.com', 1),
#  ('brookofhope@gmail.com', 1),
#  ('chaadopt@yahoo.com', 1),
#  ('contact@ncbw-metroatlchapter.org', 1),
#  ('contact@nhrinc.org', 1),
#  ('contactus@brunswickfoodpantry.org', 1),
#  ('dan@revada.org', 1),
#  ('debra.shuck@ascension.org', 1),
#  ('dianegarnetts@gmail.com', 1),
#  ('gaylordarts@gaylordarts.org', 1),
#  ('hailey@cfwjackson.org', 1),
#  ('hhhope@verizon.net', 1),
#  ('info@bridgingthegapafrica.org', 1),
#  ('info@bruknernaturecenter.com', 1),
#  ('info@coasjc.org', 1),
#  ('info@greenvilletransmissionclinic.com', 1),
#  ('info@hcffcharities.com', 1),
#  ('info@kchftv.org', 1),
#  ('info@nakashimafoundation.org', 1),
#  ('info@ndsccenter.org', 1),
#  ('info@nextstepp.org', 1),
#  ('info@pathwayindy.org', 1),
#  ('info@reachavillage.org', 1),
#  ('info@renovateall.org', 1),
#  ('info@taliaslegacy.org', 1),
#  ('info@teamgear.org', 1),
#  ('jdaffner@mbdcounsel.com', 1),
#  ('joincarttoday@gmail.com', 1),
#  ('naomisplacewomen@yahoo.com', 1),
#  ('office@oakspringcemetery.com', 1),
#  ('pp2crescue@gmail.com', 1),
#  ('qcpaws@yahoo.com', 1),
#  ('redemptanfp@yahoo.com', 1),
#  ('rfkbaade@yahoo.com', 1),
#  ('rgordon@rmhfoundation.org', 1),
#  ('richardsvillefireandrescue@gmail.com', 1),
#  ('ridewithvalor@gmail.com', 1),
#  ('saturdaymkt@yahoo.com', 1),
#  ('statesboroexchangeclub@gmail.com', 1),
#  ('wcharles@brightfutureforkids.com', 1),
#  ('zach@broadleafwriters.com', 1)]

# %%
# Created a new dataframe with the sorted data
sorted_welcome_message_df = pd.DataFrame(columns = ["Email address", "First name", "Last name", "Company","Opened At"])
for item in sorted_emails:
   entry = welcome_message_df[welcome_message_df["Email address"] == item[0]]
   sorted_welcome_message_df = pd.concat([sorted_welcome_message_df,entry])

sorted_welcome_message_df
# Out:
#                         Email address First name Last name  \
# 50                     info@refed.org       Dana   Gunders
# 697                    info@refed.org       Dana   Gunders
# 698                    info@refed.org       Dana   Gunders
# 699                    info@refed.org       Dana   Gunders
# 700                    info@refed.org       Dana   Gunders
# ..                                ...        ...       ...
# 79            ridewithvalor@gmail.com    Russell     Rhoda
# 80              saturdaymkt@yahoo.com      David   Goodwin
# 83   statesboroexchangeclub@gmail.com    Christy   Kennedy
# 84   wcharles@brightfutureforkids.com      Widza  Robinson
# 87          zach@broadleafwriters.com    Zachary    Stevie
#
#                                             Company         Opened At  \
# 50                                       Refed Inc.               NaN
# 697                                      Refed Inc.  10/1/2024 9:22am
# 698                                      Refed Inc.  9/30/2024 9:46am
# 699                                      Refed Inc.  9/30/2024 9:45am
# 700                                      Refed Inc.  9/30/2024 9:36am
# ..                                              ...               ...
# 79                             Ride With Valor Inc.  10/2/2024 8:53am
# 80      St. Petersburg Saturday Morning Market Inc.  10/2/2024 2:42pm
# 83   NATIONAL EXCHANGE CLUB STATESBORO GA CLUB 2588  10/2/2024 8:30am
# 84                       Bright Future For Kids Inc  10/2/2024 8:31am
# 87               Broadleaf Writers Association Inc.  10/2/2024 8:48am
#
#                      Clicked Link Address        Clicked At
# 50   https://group22team.com/gold-package  9/30/2024 9:11am
# 697                                   NaN               NaN
# 698                                   NaN               NaN
# 699                                   NaN               NaN
# 700                                   NaN               NaN
# ..                                    ...               ...
# 79                                    NaN               NaN
# 80                                    NaN               NaN
# 83                                    NaN               NaN
# 84                                    NaN               NaN
# 87                                    NaN               NaN
#
# [1444 rows x 7 columns]

# %% [markdown]
# ##### Basic Analysis

# %%
# Calculated percentage of messages opened
not_opened = sorted_welcome_message_df["Opened At"].isna().sum()
total_msg = sorted_welcome_message_df["Opened At"].count()

print(f'{not_opened} out of {total_msg} messages were not opened')
print(f'{(not_opened/total_msg).round(2)}% of messages were not opened, meaning {1-(not_opened/total_msg).round(2)}% of messages were opened')
# Out:
# 76 out of 1368 messages were not opened
# 0.06% of messages were not opened, meaning 0.94% of messages were opened

# %%
# Found the emails with the highest number of clicks
welcome_msg_sort = pd.DataFrame(sorted_emails, columns=["Email", "Number of Click/Opened Data"])
welcome_msg_sort
# Out:
#                                 Email  Number of Click/Opened Data
# 0                      info@refed.org                           10
# 1                 pvelempto@gmail.com                            9
# 2                    vbaker@sjcds.net                            9
# 3               info@nbnfoundation.us                            8
# 4         info@cleanlakesalliance.org                            8
# ..                                ...                          ...
# 828           ridewithvalor@gmail.com                            1
# 829             saturdaymkt@yahoo.com                            1
# 830  statesboroexchangeclub@gmail.com                            1
# 831  wcharles@brightfutureforkids.com                            1
# 832         zach@broadleafwriters.com                            1
#
# [833 rows x 2 columns]

# %% [markdown]
# ### Engagement Levels for Message 2 - Success Story (Sent 11/2024, Resent 10/2/24)

# %% [markdown]
# ##### Exploratory Data Analysis

# %%
# Created a dataframe that includes all excel sheets for message 2
ss_df = pd.concat([ss_original_clicked_df, ss_original_opened_df, ss_resend_clicked_df, ss_resend_opened_df])
ss_df
# Out:
#                      Email address First name Last name  \
# 0                amvets@amvets.org     Horace   Johnson
# 1                amvets@amvets.org     Horace   Johnson
# 2                amvets@amvets.org     Horace   Johnson
# 3                amvets@amvets.org     Horace   Johnson
# 4                   artm@tdshc.org       Rose    Garcia
# ..                             ...        ...       ...
# 57  thecoleys@labridocumentary.com    Houston     Coley
# 58      thoreau@navajochapters.org      Clara    Toledo
# 59   tjones.peerrecovery@gmail.com      Keith     Owens
# 60         ttouhy@chicagoriver.org        Tim     Touhy
# 61         westbrookepto@gmail.com    Brieann     Byers
#
#                                  Company  \
# 0                                 Amvets
# 1                                 Amvets
# 2                                 Amvets
# 3                                 Amvets
# 4     Tierra Del Sol Housing Corporation
# ..                                   ...
# 57                        Art Within Inc
# 58  Thoreau Navajo Outreach Incorporated
# 59         Peer Recovery Connection Inc.
# 60          Friends of the Chicago River
# 61        Westbrooke Elementary Pto Inc.
#
#                                  Clicked Link Address        Clicked At  \
# 0                https://group22team.com/testimonials  9/25/2024 8:21am
# 1         https://www.instagram.com/group22nonprofit/  9/25/2024 8:21am
# 2   https://calendly.com/marcusgroup22/free-consul...  9/25/2024 8:21am
# 3                          https://www.mowdurham.org/  9/25/2024 8:21am
# 4                https://group22team.com/testimonials  9/25/2024 8:21am
# ..                                                ...               ...
# 57                                                NaN               NaN
# 58                                                NaN               NaN
# 59                                                NaN               NaN
# 60                                                NaN               NaN
# 61                                                NaN               NaN
#
#    Email status          Opened At
# 0           NaN                NaN
# 1           NaN                NaN
# 2           NaN                NaN
# 3           NaN                NaN
# 4           NaN                NaN
# ..          ...                ...
# 57          NaN   9/27/2024 9:26am
# 58          NaN   9/29/2024 6:54am
# 59          NaN   9/27/2024 8:46am
# 60          NaN  9/27/2024 11:21am
# 61          NaN   9/27/2024 7:06pm
#
# [1381 rows x 8 columns]

# %%
# Check size of the data frame
ss_df.shape
# Out:
# (1381, 8)

# %%
# Checked data type of the data frame
ss_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1381 entries, 0 to 61
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Email address         1381 non-null   object
#  1   First name            1381 non-null   object
#  2   Last name             1365 non-null   object
#  3   Company               1381 non-null   object
#  4   Clicked Link Address  425 non-null    object
#  5   Clicked At            425 non-null    object
#  6   Email status          894 non-null    object
#  7   Opened At             956 non-null    object
# dtypes: object(8)
# memory usage: 97.1+ KB

# %% [markdown]
# ##### Engagement Levels

# %%
# Created a dictionary containing all emails in the dataset as well as how often they appear
email_count = {}
multiple_instances = []

for email in ss_df["Email address"]:
    if email in email_count:
        email_count[email] += 1
    else:
        email_count[email] = 1

email_count
# Out:
# {'amvets@amvets.org': 6,
#  'artm@tdshc.org': 7,
#  'ashrae@ashrae.org': 6,
#  'barb.hailey@lssi.org': 5,
#  'bmiller@latwp.org': 5,
#  'brianna.jones@sr-ahec.org': 6,
#  'brinker_t@hcsb.k12.fl.us': 6,
#  'cameron@mcysb.org': 6,
#  'caprockfoundation@chhsi.com': 7,
#  'celebrate@showandheal.org': 6,
#  'chief@opvrs.com': 6,
#  'chris@warriorwellnessprogram.org': 5,
#  'ckwri@tamuk.edu': 6,
#  'communications@apwu.org': 5,
#  'contactus@jamskenya.org': 7,
#  'ddoubleday@careersourceheartland.com': 7,
#  'debra@heightsfoundation.org': 6,
#  'donna@canineclassmates.org': 7,
#  'fmca@dia.org': 6,
#  'fmccs@mccsc.edu': 9,
#  'foundation@mchenry.edu': 8,
#  'global@drexel.edu': 6,
#  'gosocial@piedmonthousing.org': 6,
#  'grants@brownfoundation.org': 5,
#  'greatlakes@mcc.org': 5,
#  'heather@thebugleboy.org': 7,
#  'help@namb.net': 6,
#  'hfm@hfmich.org': 6,
#  'holly@tomorrowswomen.org': 6,
#  'hope@inprem.org': 2,
#  'info@100club.org': 6,
#  'info@atlantachildren.org': 5,
#  'info@bebglobal.org': 8,
#  'info@benefitcostanalysis.org': 13,
#  'info@bgcneo.org': 6,
#  'info@blackdogcharity.com': 6,
#  'info@bleedingdisordersfl.org': 7,
#  'info@brightonsa.org': 7,
#  'info@cacgrants.org': 6,
#  'info@ccppi.org': 9,
#  'info@collaboratory.org': 5,
#  'info@encouragementcafe.com': 6,
#  'info@friendschicago.org': 6,
#  'info@frontierus.org': 6,
#  'info@globaltiesabq.org': 6,
#  'info@gnfcc.com': 6,
#  'info@heartofadoptions.com': 7,
#  'info@heathcotebg.org': 6,
#  'info@helpcdc.org': 6,
#  'info@helpnowshelter.org': 6,
#  'info@hillsanddales.org': 5,
#  'info@igschools.org': 6,
#  'info@loveranred.org': 6,
#  'info@mainlineart.org': 6,
#  'info@maito.org': 7,
#  'info@massillonkids.org': 7,
#  'info@mbcdc.org': 6,
#  'info@mccormick.us': 6,
#  'info@mosaicunited.org': 6,
#  'info@na3rsc.org': 6,
#  'info@parkviewmission.org': 7,
#  'info@peopleinc.net': 6,
#  'info@phillypal.org': 6,
#  'info@pmmifoundation.org': 12,
#  'info@portco.org': 7,
#  'info@positivepathsaz.org': 6,
#  'info@prepassalliance.org': 6,
#  'info@sosflorida.com': 6,
#  'info@spacecoastdiscovery.org': 6,
#  'info@wakebgc.org': 6,
#  'info@wecaremanatee.org': 10,
#  'info@wellspringmiami.org': 8,
#  'inform@bcworkshop.org': 3,
#  'information@fspcares.org': 6,
#  'intake@nicholashouse.org': 6,
#  'ipjc@ipjc.org': 6,
#  'iusm@iu.edu': 7,
#  'jalen@unm.edu': 7,
#  'johnnywilson@fayurbmin.org': 6,
#  'jon@nb3f.org': 6,
#  'khamann@kzcf.org': 7,
#  'kmonroe@brazosbendguardianship.org': 6,
#  'leigh.fowler@northgatech.edu': 5,
#  'lisa.tolley@deq.nc.gov': 5,
#  'lovecradleint@lovecradleint.org': 6,
#  'mailbox@bcfy.org': 6,
#  'mdarrow@feedingthecarolinas.org': 7,
#  'membership@piedmontymca.org': 6,
#  'membership@shrinenet.org': 6,
#  'mnewman@engelhardmedicalcenter.org': 6,
#  'office@ujimafoundation.org': 7,
#  'parks@ingham.org': 6,
#  'pff@partnershipforthefuture.org': 6,
#  'president@templeofpeace.org': 5,
#  's.mahone9945@comcast.net': 2,
#  'secretary@njslserves.org': 6,
#  'sivagj@bgsu.edu': 5,
#  'support@beinmotion.org': 7,
#  'susan.worsley@angelhousega.com': 6,
#  'susan@neuroamerica.org': 6,
#  'teresal@hacfm.org': 6,
#  'trescoworks@trescoinc.org': 5,
#  'usa@watoto.com': 9,
#  'wastenot@wastenotflorida.com': 6,
#  'webinfo@juf.org': 5,
#  '8401@elkinrescuesquad.org': 1,
#  'aboundinginlove@aboundinginlove.org': 1,
#  'admissions@mainlineclassical.org': 2,
#  'adoptafurrcat@gmail.com': 1,
#  'adoptions@mchumanesoc.org': 1,
#  'afamilylifeskillscenter@gmail.com': 1,
#  'ajvolleyballbooster@gmail.com': 2,
#  'alan77505@att.net': 1,
#  'allentownpalprogram@gmail.com': 2,
#  'ally@abeautifulme.com': 2,
#  'amehalko@icloud.com': 1,
#  'anchorhousecm@gmail.com': 2,
#  'andy@energizeministries.com': 2,
#  'angela@thewholeness.org': 2,
#  'aohfoundation@gmail.com': 1,
#  'apha-asp@aphanet.org': 1,
#  'apor.ministries.swd@gmail.com': 1,
#  'arnie@w4lmoz.com': 2,
#  'athensmunicipallibrary@gmail.com': 1,
#  'bhf@brazoriahf.org': 1,
#  'bianca@southernshakes.org': 2,
#  'bill@thecoffeetrust.org': 2,
#  'billsbackpacks806@gmail.com': 1,
#  'boxoffice@santafeopera.org': 1,
#  'boystomenstaff@btmth.org': 3,
#  'bpeters@mooresvillechristian.org': 1,
#  'bradysbridge@gmail.com': 1,
#  'brickcityblastbaseballclub@gmail.com': 1,
#  'brooke@wellfitgirls.org': 1,
#  'buddypowerpromotions@gmail.com': 1,
#  'bustersfriendsrescue@gmail.com': 2,
#  'cancercures4kids@gmail.com': 1,
#  'care@1010ministries.org': 1,
#  'casa@casaforhuntcounty.org': 1,
#  'casaverdecats@gmail.com': 1,
#  'cat.wren@businessjetcenter.com': 1,
#  'ccullum02@comcast.net': 1,
#  'central.office@interalliance.org': 1,
#  'cfoh@cfohtown.com': 2,
#  'childadvocacy@madisoncountyil.gov': 1,
#  'christforcuba@gmail.com': 1,
#  'cityofpeaceministries@yahoo.com': 2,
#  'clark@fairviewtowncrier.com': 1,
#  'coach@apexathletixaz.com': 8,
#  'coholmes@planbeeacademy.org': 2,
#  'colin@etmnc.org': 1,
#  'comm@ngbsa.org': 2,
#  'communication@pardadapardadi.org': 1,
#  'communications@fwparker.org': 2,
#  'communications@owlvfd.org': 1,
#  'communications@thespfc.org': 1,
#  'connect@casademiel.org': 4,
#  'contact@autotraining.net': 1,
#  'contact@bravebreed.org': 3,
#  'contact@breastfeeding-boobs.com': 3,
#  'contact@hermitagecommunity.org': 1,
#  'contact@sbmcjax.com': 1,
#  'contact@tbbhi.org': 1,
#  'contactus@amotherswishmichigan.com': 2,
#  'contactus@fpofmc.org': 1,
#  'creationdoc@gmail.com': 1,
#  'daneshe.bethune@c5texas.org': 1,
#  'danny@wecansoyoucan.org': 2,
#  'david.saltlife@gmail.com': 2,
#  'david.varela@taoscountynm.gov': 1,
#  'david@angelstouchinc.org': 1,
#  'development@brazosportcares.org': 1,
#  'dhorner.efl@gmail.com': 1,
#  'director@blackactuaries.org': 1,
#  'director@friendsofprentice.org': 1,
#  'director@heartlandbaptistmissions.org': 1,
#  'director@onevirginia2021.org': 1,
#  'director@vapageone.org': 2,
#  'director@welbourneavenuenursery.org': 1,
#  'directorofoperations.tvloveinc@gmail.com': 2,
#  'djoconnell@ysu.edu': 1,
#  'donnie@misfitsministry.org': 5,
#  'drbrian@brianadamsministries.com': 1,
#  'eelka@countryside.cc': 1,
#  'elizabeth@enopublishers.org': 2,
#  'email@bgccleveco.org': 2,
#  'engage@franklincreekconservation.org': 2,
#  'enroll@pointpark.edu': 1,
#  'epeterson@wellflorida.org': 1,
#  'equinox.ranch@yahoo.com': 1,
#  'esantos@gataxclinic.com': 2,
#  'eureka@eurekahouse.org': 1,
#  'events@bgccentralohio.org': 1,
#  'events@helpusgather.org': 1,
#  'events@pmvfd.com': 1,
#  'events@siestakeychamber.com': 1,
#  'executive@aila.org': 2,
#  'executivedirector@newnancowetahistoricalsociety.com': 1,
#  'executivedirector@oasissocialministry.org': 2,
#  'facebook@ngemc.com': 1,
#  'feedingaveryfamilies@gmail.com': 2,
#  'firm@maillie.com': 2,
#  'fohravolunteer@gmail.com': 2,
#  'fosncommunications@gmail.com': 2,
#  'foundation@ldsd.org': 1,
#  'frankfortlions@gmail.com': 4,
#  'fred@farmville-arts.org': 3,
#  'friends@bigmarsh.org': 2,
#  'friends@champaign.org': 1,
#  'friends@friendsofmitchell.org': 3,
#  'friends@glencoelibrary.org': 1,
#  'friendsofamundsen@gmail.com': 2,
#  'friendsofcoonley@gmail.com': 1,
#  'friendsofeliestoun@gmail.com': 2,
#  'friendsofhoytpark@hoytpark.org': 2,
#  'friendsofmurphyschool@gmail.com': 2,
#  'friendsofskinnerwest2011@gmail.com': 1,
#  'friendsofsudercps@gmail.com': 1,
#  'gallensjsci@gmail.com': 1,
#  'gbarnum@housingresourcesinc.org': 1,
#  'general@aiga.org': 2,
#  'glen.herbert@grenadinesinitiative.org': 1,
#  'gmckinney@mlkdreamschool.org': 1,
#  'godshelpinghands.org@gmail.com': 1,
#  'governor@district3ahepa.org': 8,
#  'greenlight@freshtix.com': 4,
#  'halonokillrescue@gmail.com': 1,
#  'heartfullofheaven@gmail.com': 1,
#  'heaventoearth813@gmail.com': 1,
#  'hello@infinitechance.org': 1,
#  'hello@revolutionlancaster.com': 1,
#  'help.me@hillsupport.com': 3,
#  'help@heartlandintergroup.org': 2,
#  'helpcares@embarqmail.com': 1,
#  'hendricksavebaseball@gmail.com': 1,
#  'hendrycountyfairclew@gmail.com': 3,
#  'hhsfootballboosters16@gmail.com': 2,
#  'higginsswimmersitch@gmail.com': 2,
#  'hopeforbrevard@gmail.com': 2,
#  'hpdbluesanta@gmail.com': 1,
#  'hq@sogalfoundation.com': 1,
#  'hrphares@pvschool.com': 2,
#  'ims@imstat.org': 1,
#  'info@100blackmenofphoenix.com': 1,
#  'info@airzoo.org': 1,
#  'info@anasazi.org': 1,
#  'info@artss.org': 1,
#  'info@asrs.org': 1,
#  'info@atlantaboxerrescue.org': 3,
#  'info@atlantacricketleague.org': 11,
#  'info@atlantafreedombands.com': 2,
#  'info@augustadreamcenter.org': 3,
#  'info@austinmonitor.com': 1,
#  'info@biohouston.org': 1,
#  'info@booksbetweenkids.org': 2,
#  'info@bookspring.org': 3,
#  'info@braintreatmentfoundation.com': 1,
#  'info@braveheartministries.org': 1,
#  'info@bravelove.org': 3,
#  'info@brazosimmigration.com': 2,
#  'info@breadoflifeinc.org': 2,
#  'info@breathingassociation.org': 1,
#  'info@bridge-year.org': 1,
#  'info@bridgeafricafoundation.org': 1,
#  'info@bridgebreast.org': 1,
#  'info@bridgegateedu.org': 1,
#  'info@bridgehrc.org': 1,
#  'info@bridgingfortomorrow.org': 1,
#  'info@brightlightprojects.org': 1,
#  'info@brotherhooddallastx.org': 2,
#  'info@buffalobayou.org': 1,
#  'info@buildingcompassion.org': 1,
#  'info@bunniesonthebayou.com': 9,
#  'info@capitolviewarts.org': 2,
#  'info@carryinghope.org': 2,
#  'info@catchupandread.org': 2,
#  'info@cityofoaksfoundation.org': 2,
#  'info@dccga.org': 3,
#  'info@dogsinc.org': 1,
#  'info@downtownmoreheadcity.com': 1,
#  'info@elizabethangardens.org': 1,
#  'info@emergelanka.org': 1,
#  'info@emmauscenterforspirituality.com': 1,
#  'info@equalrightsinstitute.com': 1,
#  'info@feastdowneast.org': 3,
#  'info@foreverfamiliestx.org': 1,
#  'info@fotfp.org': 1,
#  'info@fransonrisberg.com': 2,
#  'info@friendsofburr.org': 3,
#  'info@friendsofgrparks.org': 1,
#  'info@friendsofjahn.org': 1,
#  'info@friendsoflakeview.org': 2,
#  'info@gromadacancerfndn.org': 1,
#  'info@heartsformoms.org': 1,
#  'info@heat-wave.org': 1,
#  'info@hebninutrition.org': 1,
#  'info@heelstoheal.org': 1,
#  'info@heightsfoundation.org': 2,
#  'info@helptohome.org': 1,
#  'info@hemophiliaalliancefoundation.org': 4,
#  'info@herdfoundation.org': 4,
#  'info@herfuturecoalition.org': 2,
#  'info@hermanaslatinas.org': 4,
#  'info@hhmin.org': 1,
#  'info@hrchc.org': 1,
#  'info@humanesocietyncfl.org': 3,
#  'info@inspiringmindsyouth.org': 2,
#  'info@insuringthechildren.org': 2,
#  'info@irlabnp.org': 2,
#  'info@itipohio.org': 1,
#  'info@kalamazooarts.org': 1,
#  'info@kalbookarts.org': 1,
#  'info@lbscares.org': 1,
#  'info@mapleleafjeff.org': 1,
#  'info@marinecorpsleaguepensacola.org': 1,
#  'info@mlccc.org': 1,
#  'info@mymwa.org': 2,
#  'info@ncgr.org': 1,
#  'info@newlifetechgroup.com': 1,
#  'info@newname.cc': 1,
#  'info@newpath1010.org': 1,
#  'info@newtontomorrow.org': 1,
#  'info@newtontrails.org': 2,
#  'info@nextgenatl.org': 1,
#  'info@nicoleshouseofhope.org': 1,
#  'info@nolongerorphans.org': 2,
#  'info@obicihcf.org': 1,
#  'info@onwardchristian.org': 2,
#  'info@ophrescue.org': 1,
#  'info@ourheartsofhope.org': 3,
#  'info@palmtreeschool.com': 1,
#  'info@pathwayvine.org': 2,
#  'info@pbalife.com': 1,
#  'info@pbj.org': 1,
#  'info@pennyappealusa.org': 1,
#  'info@pharva.com': 1,
#  'info@pony.org': 1,
#  'info@premieralliances.org': 2,
#  'info@prescottmealsonwheels.org': 1,
#  'info@psdpal.org': 4,
#  'info@puenteaz.org': 1,
#  'info@pvsef.org': 2,
#  'info@rescuevillage.org': 1,
#  'info@restoreaddictionrecovery.com': 1,
#  'info@restoreelikia.org': 1,
#  'info@rhadayton.com': 6,
#  'info@saginawchamber.org': 3,
#  'info@seswa.org': 1,
#  'info@sevhumanesociety.org': 1,
#  'info@sinfoniagulfcoast.org': 1,
#  'info@singlevisioninc.org': 1,
#  'info@skinnerstrong.org': 3,
#  'info@sls.org': 1,
#  'info@smilesforsuccess.org': 2,
#  'info@smsresearchfoundation.org': 1,
#  'info@soundofpride.org': 3,
#  'info@swfloridawaterpolo.org': 1,
#  'info@texashearing.org': 2,
#  'info@theangelshouse.org': 2,
#  'info@thebridgeadaptive.org': 2,
#  'info@theskillscenter.org': 1,
#  'info@thinknewmexico.org': 1,
#  'info@truekids1.org': 1,
#  'info@unfailingloveministries.org': 2,
#  'info@usuli.org': 1,
#  'info@waldencommunityschool.com': 2,
#  'info@waltonedfoundation.org': 1,
#  'info@waterfrontmission.org': 2,
#  'info@waysidehouse.net': 2,
#  'info@wecanbeheroesfoundation.org': 1,
#  'info@wecaresupport.org': 2,
#  'info@westvolusiahistoricalsociety.org': 1,
#  'infopowermaxco@gmail.com': 2,
#  'information@sezarc.com': 1,
#  'information@sunriseseniorliving.com': 1,
#  'inspireaviationfoundation@gmail.com': 2,
#  'inst4medstudies@gmail.com': 2,
#  'interact@sitetackle.com': 3,
#  'jana@buildingfamiliesfortomorrow.com': 1,
#  'jeff@simplysports.net': 1,
#  'jennifer@howflorida.org': 2,
#  'jennifer@mistyeyes.org': 2,
#  'jordanhollins3@gmail.com': 1,
#  'joy.baldree@newmycro.org': 3,
#  'joy@bcfundofohio.org': 1,
#  'jray@ngcainc.com': 1,
#  'jwalker@watchman.org': 2,
#  'kairosdwelling@aol.com': 2,
#  'kar@kalamazooanimalrescue.org': 2,
#  'kenjonespastor@practicallivingministry.org': 1,
#  'kim@spacebetween.community': 1,
#  'l.rothman@haape.org': 3,
#  'ldelk@nextgenerationspeech.org': 1,
#  'lee.rogers@igworks.org': 1,
#  'lindsay@heartgallerytampa.org': 2,
#  'lisa.noss@sigsbee.org': 1,
#  'lisa@brewhausdogbones.com': 1,
#  'littlemiracleslearn@gmail.com': 1,
#  'lnohra@pfva.org': 1,
#  'love4liamorg@gmail.com': 1,
#  'lovingcarecatrescue@gmail.com': 1,
#  'lpulliam@patrickhenry.edu': 2,
#  'mail@pattyshope.org': 1,
#  'maliprantis@primehealthcare.com': 1,
#  'managing@thebrecksvilletheatre.org': 1,
#  'marianoasis7@gmail.com': 1,
#  'marionhumane@gmail.com': 4,
#  'maumee@insideoutrecreation.com': 1,
#  'mbasis@wcflfootball.com': 1,
#  'mbryant@newlife-atl.org': 1,
#  'megan@ninelinefoundation.org': 5,
#  'membership@biaoh.org': 1,
#  'michaalrossi@gmail.com': 1,
#  'michelle@hearts-hands-hope.org': 1,
#  'mklevan@mklevanlaw.com': 2,
#  'mnsboard@medaryvillenurseryschool.com': 6,
#  'mvfc@ptd.net': 1,
#  'nachusagrasslands@gmail.com': 3,
#  'nahsfinfo@gmail.com': 1,
#  'ncesstarspto@gmail.com': 1,
#  'nchs@nchsrescue.org': 1,
#  'nctdclub@gmail.com': 1,
#  'newlifepraisecenter@gmail.com': 2,
#  'ngsgmregister17@gmail.com': 3,
#  'nicholscenter.recovery@gmail.com': 1,
#  'nicksheahan88@gmail.com': 4,
#  'nobleworld.info@gmail.com': 1,
#  'nokillglynncounty@gmail.com': 1,
#  'northatldance@gmail.com': 1,
#  'office.anniesartattic@gmail.com': 1,
#  'office@campdeerrun.com': 2,
#  'office@hth.org': 1,
#  'office@mbcyorktown.com': 1,
#  'office@nlfglobal.org': 1,
#  'office@rejoycefulrescue.com': 4,
#  'office@wastetocharity.org': 3,
#  'office@wellmontacademy.com': 3,
#  'officemanager@velouchiusa.com': 1,
#  'olddominionhumanesociety@gmail.com': 1,
#  'orlind@freshlenschicago.org': 2,
#  'pageallianceforcommunityaction@gmail.com': 1,
#  'partneringwithus@fhi360.org': 1,
#  'pasforglobalhealth@gmail.com': 1,
#  'pawsofswva@yahoo.com': 1,
#  'pawuic1@gmail.com': 3,
#  'pcollier@wfahec.org': 1,
#  'pcpresofc@prescott.edu': 2,
#  'pelmore@careersourcesouthwestflorida.com': 1,
#  'petersonfriends@gmail.com': 2,
#  'php.fauquier@aol.com': 1,
#  'pineyriverfiredept@gmail.com': 1,
#  'pmiller@pleasantviewinc.org': 1,
#  'poochkabooseinc@gmail.com': 1,
#  'positivepawsk9@gmail.com': 3,
#  'powedfoundboard@gmail.com': 1,
#  'prayfirstmm@gmail.com': 1,
#  'preservation@savewright.org': 1,
#  'president@ajhsbaseball.org': 1,
#  'rachel.muha@gmail.com': 2,
#  'rebecca@cuanm.org': 2,
#  'recruitment@powhatanrescue.com': 6,
#  'robnpaula@aol.com': 1,
#  'sam@samnational.org': 1,
#  'samhughespta@gmail.com': 2,
#  'satterlyj@wa.edu': 1,
#  'service@1veteranfoundation.org': 3,
#  'services@americanyouthfootball.com': 3,
#  'sgagliardi@azpta.org': 1,
#  'sinisterwisdom@gmail.com': 1,
#  'socialmedia@firdeusfriends.org': 1,
#  'sophiescircledogrescue@gmail.com': 1,
#  'sorrentobaberuthpresident@gmail.com': 2,
#  'southernbirthjustice@gmail.com': 1,
#  'southtexasbobwhite@texasbrigades.org': 1,
#  'station17polk@gmail.com': 1,
#  'support@clubrunner.ca': 1,
#  'support@hrhn.org': 1,
#  'support@newperspective.org': 2,
#  'support@objectivestandard.org': 1,
#  'support@taosfootwear.com': 3,
#  'tamar@treenm.org': 1,
#  'tami@helpadiabeticchild.org': 1,
#  'temple6afam@gmail.com': 2,
#  'terry.epi4dogs@gmail.com': 3,
#  'thebridge@tbotw.org': 1,
#  'theoreader@gmail.com': 1,
#  'thinktreesnm@gmail.com': 1,
#  'thoreau@navajochapters.org': 2,
#  'tjones.peerrecovery@gmail.com': 2,
#  'tkyyhd@aol.com': 1,
#  'toytraindepot.nm@gmail.com': 1,
#  'tpeters@fayettevillechristian.com': 2,
#  'tpscministry7@gmail.com': 5,
#  'trobinson@nextstepmin.org': 2,
#  'troy_forte@carrcares.org': 1,
#  'ttgraves2015@icloud.com': 1,
#  'tucmainstreetdirector@gmail.com': 1,
#  'unitedfitnm@gmail.com': 2,
#  'vcrec@hernandosc.com': 3,
#  'vets@hhveterans.com': 4,
#  'victoria.n@westcitrussoccer.com': 1,
#  'volunteer@powhatanva.gov': 1,
#  'wayne.price@schfbrevard.org': 1,
#  'welcome@hendryfla.net': 2,
#  'wellingtonvolleyballacademy@gmail.com': 3,
#  'whatifworks@gmail.com': 1,
#  'winnerscirclecharities@gmail.com': 1,
#  'wpbrotaryclub@gmail.com': 1,
#  'youngstown@inspiringmindsyouth.org': 3,
#  'zander@forestguild.org': 1,
#  'president@pulmonarypath.org': 2,
#  'pgibson@wakehealth.edu': 6,
#  'joi.blume@generalstar.com': 6,
#  'bbhhsaa@gmail.com': 1,
#  'bhoward@friendsofthecoronado.org': 1,
#  'cassie.jones@epiphanyschoolofcharlotte.com': 1,
#  'cassiesplace@yahoo.com': 1,
#  'eetc@eetc.org': 2,
#  'ethan@logmichiana.org': 1,
#  'friendsofsauganashnews@gmail.com': 1,
#  'hamtramckhistory@gmail.com': 1,
#  'hello@solidrockflorida.org': 1,
#  'inc_footprints@yahoo.com': 1,
#  'info@buckfever.org': 1,
#  'info@elkinvalleytrails.org': 1,
#  'info@emancipatenc.org': 1,
#  'info@floridajewishacademy.org': 1,
#  'info@franciscanworks.org': 1,
#  'info@friendsofmichigan.org': 1,
#  'info@highwayconnections.org': 1,
#  'info@lblax.org': 1,
#  'info@migrosaid.org': 1,
#  'info@nishkamusa.org': 2,
#  'info@ohacenter.org': 1,
#  'info@ourcommunityplace.org': 1,
#  'info@prakashministries.com': 1,
#  'info@smbs.org': 1,
#  'info@v2ga.org': 1,
#  'janetflomax@icloud.com': 1,
#  'larry@lawm.global': 2,
#  'newtown193@gmail.com': 1,
#  'nsm@nextstepministries.net': 1,
#  'nyaa.information@yahoo.com': 1,
#  'piedmontcharitablefoundation@gmail.com': 1,
#  'sahummel@ptd.net': 1,
#  'stacyg@newtonclc.com': 1,
#  'stephanie@letsthrivenm.org': 1,
#  'sundax@gmail.com': 1,
#  't.conway@ewrunnerctr.org': 1,
#  'terry@a2ministries.com': 1,
#  'thecoleys@labridocumentary.com': 1,
#  'ttouhy@chicagoriver.org': 1,
#  'westbrookepto@gmail.com': 1}

# %%
# Sorted the dictionary from highest key value to lowest
sorted_emails = sorted(email_count.items(), key=lambda x: x[1], reverse=True)
sorted_emails
# Out:
# [('info@benefitcostanalysis.org', 13),
#  ('info@pmmifoundation.org', 12),
#  ('info@atlantacricketleague.org', 11),
#  ('info@wecaremanatee.org', 10),
#  ('fmccs@mccsc.edu', 9),
#  ('info@ccppi.org', 9),
#  ('usa@watoto.com', 9),
#  ('info@bunniesonthebayou.com', 9),
#  ('foundation@mchenry.edu', 8),
#  ('info@bebglobal.org', 8),
#  ('info@wellspringmiami.org', 8),
#  ('coach@apexathletixaz.com', 8),
#  ('governor@district3ahepa.org', 8),
#  ('artm@tdshc.org', 7),
#  ('caprockfoundation@chhsi.com', 7),
#  ('contactus@jamskenya.org', 7),
#  ('ddoubleday@careersourceheartland.com', 7),
#  ('donna@canineclassmates.org', 7),
#  ('heather@thebugleboy.org', 7),
#  ('info@bleedingdisordersfl.org', 7),
#  ('info@brightonsa.org', 7),
#  ('info@heartofadoptions.com', 7),
#  ('info@maito.org', 7),
#  ('info@massillonkids.org', 7),
#  ('info@parkviewmission.org', 7),
#  ('info@portco.org', 7),
#  ('iusm@iu.edu', 7),
#  ('jalen@unm.edu', 7),
#  ('khamann@kzcf.org', 7),
#  ('mdarrow@feedingthecarolinas.org', 7),
#  ('office@ujimafoundation.org', 7),
#  ('support@beinmotion.org', 7),
#  ('amvets@amvets.org', 6),
#  ('ashrae@ashrae.org', 6),
#  ('brianna.jones@sr-ahec.org', 6),
#  ('brinker_t@hcsb.k12.fl.us', 6),
#  ('cameron@mcysb.org', 6),
#  ('celebrate@showandheal.org', 6),
#  ('chief@opvrs.com', 6),
#  ('ckwri@tamuk.edu', 6),
#  ('debra@heightsfoundation.org', 6),
#  ('fmca@dia.org', 6),
#  ('global@drexel.edu', 6),
#  ('gosocial@piedmonthousing.org', 6),
#  ('help@namb.net', 6),
#  ('hfm@hfmich.org', 6),
#  ('holly@tomorrowswomen.org', 6),
#  ('info@100club.org', 6),
#  ('info@bgcneo.org', 6),
#  ('info@blackdogcharity.com', 6),
#  ('info@cacgrants.org', 6),
#  ('info@encouragementcafe.com', 6),
#  ('info@friendschicago.org', 6),
#  ('info@frontierus.org', 6),
#  ('info@globaltiesabq.org', 6),
#  ('info@gnfcc.com', 6),
#  ('info@heathcotebg.org', 6),
#  ('info@helpcdc.org', 6),
#  ('info@helpnowshelter.org', 6),
#  ('info@igschools.org', 6),
#  ('info@loveranred.org', 6),
#  ('info@mainlineart.org', 6),
#  ('info@mbcdc.org', 6),
#  ('info@mccormick.us', 6),
#  ('info@mosaicunited.org', 6),
#  ('info@na3rsc.org', 6),
#  ('info@peopleinc.net', 6),
#  ('info@phillypal.org', 6),
#  ('info@positivepathsaz.org', 6),
#  ('info@prepassalliance.org', 6),
#  ('info@sosflorida.com', 6),
#  ('info@spacecoastdiscovery.org', 6),
#  ('info@wakebgc.org', 6),
#  ('information@fspcares.org', 6),
#  ('intake@nicholashouse.org', 6),
#  ('ipjc@ipjc.org', 6),
#  ('johnnywilson@fayurbmin.org', 6),
#  ('jon@nb3f.org', 6),
#  ('kmonroe@brazosbendguardianship.org', 6),
#  ('lovecradleint@lovecradleint.org', 6),
#  ('mailbox@bcfy.org', 6),
#  ('membership@piedmontymca.org', 6),
#  ('membership@shrinenet.org', 6),
#  ('mnewman@engelhardmedicalcenter.org', 6),
#  ('parks@ingham.org', 6),
#  ('pff@partnershipforthefuture.org', 6),
#  ('secretary@njslserves.org', 6),
#  ('susan.worsley@angelhousega.com', 6),
#  ('susan@neuroamerica.org', 6),
#  ('teresal@hacfm.org', 6),
#  ('wastenot@wastenotflorida.com', 6),
#  ('info@rhadayton.com', 6),
#  ('mnsboard@medaryvillenurseryschool.com', 6),
#  ('recruitment@powhatanrescue.com', 6),
#  ('pgibson@wakehealth.edu', 6),
#  ('joi.blume@generalstar.com', 6),
#  ('barb.hailey@lssi.org', 5),
#  ('bmiller@latwp.org', 5),
#  ('chris@warriorwellnessprogram.org', 5),
#  ('communications@apwu.org', 5),
#  ('grants@brownfoundation.org', 5),
#  ('greatlakes@mcc.org', 5),
#  ('info@atlantachildren.org', 5),
#  ('info@collaboratory.org', 5),
#  ('info@hillsanddales.org', 5),
#  ('leigh.fowler@northgatech.edu', 5),
#  ('lisa.tolley@deq.nc.gov', 5),
#  ('president@templeofpeace.org', 5),
#  ('sivagj@bgsu.edu', 5),
#  ('trescoworks@trescoinc.org', 5),
#  ('webinfo@juf.org', 5),
#  ('donnie@misfitsministry.org', 5),
#  ('megan@ninelinefoundation.org', 5),
#  ('tpscministry7@gmail.com', 5),
#  ('connect@casademiel.org', 4),
#  ('frankfortlions@gmail.com', 4),
#  ('greenlight@freshtix.com', 4),
#  ('info@hemophiliaalliancefoundation.org', 4),
#  ('info@herdfoundation.org', 4),
#  ('info@hermanaslatinas.org', 4),
#  ('info@psdpal.org', 4),
#  ('marionhumane@gmail.com', 4),
#  ('nicksheahan88@gmail.com', 4),
#  ('office@rejoycefulrescue.com', 4),
#  ('vets@hhveterans.com', 4),
#  ('inform@bcworkshop.org', 3),
#  ('boystomenstaff@btmth.org', 3),
#  ('contact@bravebreed.org', 3),
#  ('contact@breastfeeding-boobs.com', 3),
#  ('fred@farmville-arts.org', 3),
#  ('friends@friendsofmitchell.org', 3),
#  ('help.me@hillsupport.com', 3),
#  ('hendrycountyfairclew@gmail.com', 3),
#  ('info@atlantaboxerrescue.org', 3),
#  ('info@augustadreamcenter.org', 3),
#  ('info@bookspring.org', 3),
#  ('info@bravelove.org', 3),
#  ('info@dccga.org', 3),
#  ('info@feastdowneast.org', 3),
#  ('info@friendsofburr.org', 3),
#  ('info@humanesocietyncfl.org', 3),
#  ('info@ourheartsofhope.org', 3),
#  ('info@saginawchamber.org', 3),
#  ('info@skinnerstrong.org', 3),
#  ('info@soundofpride.org', 3),
#  ('interact@sitetackle.com', 3),
#  ('joy.baldree@newmycro.org', 3),
#  ('l.rothman@haape.org', 3),
#  ('nachusagrasslands@gmail.com', 3),
#  ('ngsgmregister17@gmail.com', 3),
#  ('office@wastetocharity.org', 3),
#  ('office@wellmontacademy.com', 3),
#  ('pawuic1@gmail.com', 3),
#  ('positivepawsk9@gmail.com', 3),
#  ('service@1veteranfoundation.org', 3),
#  ('services@americanyouthfootball.com', 3),
#  ('support@taosfootwear.com', 3),
#  ('terry.epi4dogs@gmail.com', 3),
#  ('vcrec@hernandosc.com', 3),
#  ('wellingtonvolleyballacademy@gmail.com', 3),
#  ('youngstown@inspiringmindsyouth.org', 3),
#  ('hope@inprem.org', 2),
#  ('s.mahone9945@comcast.net', 2),
#  ('admissions@mainlineclassical.org', 2),
#  ('ajvolleyballbooster@gmail.com', 2),
#  ('allentownpalprogram@gmail.com', 2),
#  ('ally@abeautifulme.com', 2),
#  ('anchorhousecm@gmail.com', 2),
#  ('andy@energizeministries.com', 2),
#  ('angela@thewholeness.org', 2),
#  ('arnie@w4lmoz.com', 2),
#  ('bianca@southernshakes.org', 2),
#  ('bill@thecoffeetrust.org', 2),
#  ('bustersfriendsrescue@gmail.com', 2),
#  ('cfoh@cfohtown.com', 2),
#  ('cityofpeaceministries@yahoo.com', 2),
#  ('coholmes@planbeeacademy.org', 2),
#  ('comm@ngbsa.org', 2),
#  ('communications@fwparker.org', 2),
#  ('contactus@amotherswishmichigan.com', 2),
#  ('danny@wecansoyoucan.org', 2),
#  ('david.saltlife@gmail.com', 2),
#  ('director@vapageone.org', 2),
#  ('directorofoperations.tvloveinc@gmail.com', 2),
#  ('elizabeth@enopublishers.org', 2),
#  ('email@bgccleveco.org', 2),
#  ('engage@franklincreekconservation.org', 2),
#  ('esantos@gataxclinic.com', 2),
#  ('executive@aila.org', 2),
#  ('executivedirector@oasissocialministry.org', 2),
#  ('feedingaveryfamilies@gmail.com', 2),
#  ('firm@maillie.com', 2),
#  ('fohravolunteer@gmail.com', 2),
#  ('fosncommunications@gmail.com', 2),
#  ('friends@bigmarsh.org', 2),
#  ('friendsofamundsen@gmail.com', 2),
#  ('friendsofeliestoun@gmail.com', 2),
#  ('friendsofhoytpark@hoytpark.org', 2),
#  ('friendsofmurphyschool@gmail.com', 2),
#  ('general@aiga.org', 2),
#  ('help@heartlandintergroup.org', 2),
#  ('hhsfootballboosters16@gmail.com', 2),
#  ('higginsswimmersitch@gmail.com', 2),
#  ('hopeforbrevard@gmail.com', 2),
#  ('hrphares@pvschool.com', 2),
#  ('info@atlantafreedombands.com', 2),
#  ('info@booksbetweenkids.org', 2),
#  ('info@brazosimmigration.com', 2),
#  ('info@breadoflifeinc.org', 2),
#  ('info@brotherhooddallastx.org', 2),
#  ('info@capitolviewarts.org', 2),
#  ('info@carryinghope.org', 2),
#  ('info@catchupandread.org', 2),
#  ('info@cityofoaksfoundation.org', 2),
#  ('info@fransonrisberg.com', 2),
#  ('info@friendsoflakeview.org', 2),
#  ('info@heightsfoundation.org', 2),
#  ('info@herfuturecoalition.org', 2),
#  ('info@inspiringmindsyouth.org', 2),
#  ('info@insuringthechildren.org', 2),
#  ('info@irlabnp.org', 2),
#  ('info@mymwa.org', 2),
#  ('info@newtontrails.org', 2),
#  ('info@nolongerorphans.org', 2),
#  ('info@onwardchristian.org', 2),
#  ('info@pathwayvine.org', 2),
#  ('info@premieralliances.org', 2),
#  ('info@pvsef.org', 2),
#  ('info@smilesforsuccess.org', 2),
#  ('info@texashearing.org', 2),
#  ('info@theangelshouse.org', 2),
#  ('info@thebridgeadaptive.org', 2),
#  ('info@unfailingloveministries.org', 2),
#  ('info@waldencommunityschool.com', 2),
#  ('info@waterfrontmission.org', 2),
#  ('info@waysidehouse.net', 2),
#  ('info@wecaresupport.org', 2),
#  ('infopowermaxco@gmail.com', 2),
#  ('inspireaviationfoundation@gmail.com', 2),
#  ('inst4medstudies@gmail.com', 2),
#  ('jennifer@howflorida.org', 2),
#  ('jennifer@mistyeyes.org', 2),
#  ('jwalker@watchman.org', 2),
#  ('kairosdwelling@aol.com', 2),
#  ('kar@kalamazooanimalrescue.org', 2),
#  ('lindsay@heartgallerytampa.org', 2),
#  ('lpulliam@patrickhenry.edu', 2),
#  ('mklevan@mklevanlaw.com', 2),
#  ('newlifepraisecenter@gmail.com', 2),
#  ('office@campdeerrun.com', 2),
#  ('orlind@freshlenschicago.org', 2),
#  ('pcpresofc@prescott.edu', 2),
#  ('petersonfriends@gmail.com', 2),
#  ('rachel.muha@gmail.com', 2),
#  ('rebecca@cuanm.org', 2),
#  ('samhughespta@gmail.com', 2),
#  ('sorrentobaberuthpresident@gmail.com', 2),
#  ('support@newperspective.org', 2),
#  ('temple6afam@gmail.com', 2),
#  ('thoreau@navajochapters.org', 2),
#  ('tjones.peerrecovery@gmail.com', 2),
#  ('tpeters@fayettevillechristian.com', 2),
#  ('trobinson@nextstepmin.org', 2),
#  ('unitedfitnm@gmail.com', 2),
#  ('welcome@hendryfla.net', 2),
#  ('president@pulmonarypath.org', 2),
#  ('eetc@eetc.org', 2),
#  ('info@nishkamusa.org', 2),
#  ('larry@lawm.global', 2),
#  ('8401@elkinrescuesquad.org', 1),
#  ('aboundinginlove@aboundinginlove.org', 1),
#  ('adoptafurrcat@gmail.com', 1),
#  ('adoptions@mchumanesoc.org', 1),
#  ('afamilylifeskillscenter@gmail.com', 1),
#  ('alan77505@att.net', 1),
#  ('amehalko@icloud.com', 1),
#  ('aohfoundation@gmail.com', 1),
#  ('apha-asp@aphanet.org', 1),
#  ('apor.ministries.swd@gmail.com', 1),
#  ('athensmunicipallibrary@gmail.com', 1),
#  ('bhf@brazoriahf.org', 1),
#  ('billsbackpacks806@gmail.com', 1),
#  ('boxoffice@santafeopera.org', 1),
#  ('bpeters@mooresvillechristian.org', 1),
#  ('bradysbridge@gmail.com', 1),
#  ('brickcityblastbaseballclub@gmail.com', 1),
#  ('brooke@wellfitgirls.org', 1),
#  ('buddypowerpromotions@gmail.com', 1),
#  ('cancercures4kids@gmail.com', 1),
#  ('care@1010ministries.org', 1),
#  ('casa@casaforhuntcounty.org', 1),
#  ('casaverdecats@gmail.com', 1),
#  ('cat.wren@businessjetcenter.com', 1),
#  ('ccullum02@comcast.net', 1),
#  ('central.office@interalliance.org', 1),
#  ('childadvocacy@madisoncountyil.gov', 1),
#  ('christforcuba@gmail.com', 1),
#  ('clark@fairviewtowncrier.com', 1),
#  ('colin@etmnc.org', 1),
#  ('communication@pardadapardadi.org', 1),
#  ('communications@owlvfd.org', 1),
#  ('communications@thespfc.org', 1),
#  ('contact@autotraining.net', 1),
#  ('contact@hermitagecommunity.org', 1),
#  ('contact@sbmcjax.com', 1),
#  ('contact@tbbhi.org', 1),
#  ('contactus@fpofmc.org', 1),
#  ('creationdoc@gmail.com', 1),
#  ('daneshe.bethune@c5texas.org', 1),
#  ('david.varela@taoscountynm.gov', 1),
#  ('david@angelstouchinc.org', 1),
#  ('development@brazosportcares.org', 1),
#  ('dhorner.efl@gmail.com', 1),
#  ('director@blackactuaries.org', 1),
#  ('director@friendsofprentice.org', 1),
#  ('director@heartlandbaptistmissions.org', 1),
#  ('director@onevirginia2021.org', 1),
#  ('director@welbourneavenuenursery.org', 1),
#  ('djoconnell@ysu.edu', 1),
#  ('drbrian@brianadamsministries.com', 1),
#  ('eelka@countryside.cc', 1),
#  ('enroll@pointpark.edu', 1),
#  ('epeterson@wellflorida.org', 1),
#  ('equinox.ranch@yahoo.com', 1),
#  ('eureka@eurekahouse.org', 1),
#  ('events@bgccentralohio.org', 1),
#  ('events@helpusgather.org', 1),
#  ('events@pmvfd.com', 1),
#  ('events@siestakeychamber.com', 1),
#  ('executivedirector@newnancowetahistoricalsociety.com', 1),
#  ('facebook@ngemc.com', 1),
#  ('foundation@ldsd.org', 1),
#  ('friends@champaign.org', 1),
#  ('friends@glencoelibrary.org', 1),
#  ('friendsofcoonley@gmail.com', 1),
#  ('friendsofskinnerwest2011@gmail.com', 1),
#  ('friendsofsudercps@gmail.com', 1),
#  ('gallensjsci@gmail.com', 1),
#  ('gbarnum@housingresourcesinc.org', 1),
#  ('glen.herbert@grenadinesinitiative.org', 1),
#  ('gmckinney@mlkdreamschool.org', 1),
#  ('godshelpinghands.org@gmail.com', 1),
#  ('halonokillrescue@gmail.com', 1),
#  ('heartfullofheaven@gmail.com', 1),
#  ('heaventoearth813@gmail.com', 1),
#  ('hello@infinitechance.org', 1),
#  ('hello@revolutionlancaster.com', 1),
#  ('helpcares@embarqmail.com', 1),
#  ('hendricksavebaseball@gmail.com', 1),
#  ('hpdbluesanta@gmail.com', 1),
#  ('hq@sogalfoundation.com', 1),
#  ('ims@imstat.org', 1),
#  ('info@100blackmenofphoenix.com', 1),
#  ('info@airzoo.org', 1),
#  ('info@anasazi.org', 1),
#  ('info@artss.org', 1),
#  ('info@asrs.org', 1),
#  ('info@austinmonitor.com', 1),
#  ('info@biohouston.org', 1),
#  ('info@braintreatmentfoundation.com', 1),
#  ('info@braveheartministries.org', 1),
#  ('info@breathingassociation.org', 1),
#  ('info@bridge-year.org', 1),
#  ('info@bridgeafricafoundation.org', 1),
#  ('info@bridgebreast.org', 1),
#  ('info@bridgegateedu.org', 1),
#  ('info@bridgehrc.org', 1),
#  ('info@bridgingfortomorrow.org', 1),
#  ('info@brightlightprojects.org', 1),
#  ('info@buffalobayou.org', 1),
#  ('info@buildingcompassion.org', 1),
#  ('info@dogsinc.org', 1),
#  ('info@downtownmoreheadcity.com', 1),
#  ('info@elizabethangardens.org', 1),
#  ('info@emergelanka.org', 1),
#  ('info@emmauscenterforspirituality.com', 1),
#  ('info@equalrightsinstitute.com', 1),
#  ('info@foreverfamiliestx.org', 1),
#  ('info@fotfp.org', 1),
#  ('info@friendsofgrparks.org', 1),
#  ('info@friendsofjahn.org', 1),
#  ('info@gromadacancerfndn.org', 1),
#  ('info@heartsformoms.org', 1),
#  ('info@heat-wave.org', 1),
#  ('info@hebninutrition.org', 1),
#  ('info@heelstoheal.org', 1),
#  ('info@helptohome.org', 1),
#  ('info@hhmin.org', 1),
#  ('info@hrchc.org', 1),
#  ('info@itipohio.org', 1),
#  ('info@kalamazooarts.org', 1),
#  ('info@kalbookarts.org', 1),
#  ('info@lbscares.org', 1),
#  ('info@mapleleafjeff.org', 1),
#  ('info@marinecorpsleaguepensacola.org', 1),
#  ('info@mlccc.org', 1),
#  ('info@ncgr.org', 1),
#  ('info@newlifetechgroup.com', 1),
#  ('info@newname.cc', 1),
#  ('info@newpath1010.org', 1),
#  ('info@newtontomorrow.org', 1),
#  ('info@nextgenatl.org', 1),
#  ('info@nicoleshouseofhope.org', 1),
#  ('info@obicihcf.org', 1),
#  ('info@ophrescue.org', 1),
#  ('info@palmtreeschool.com', 1),
#  ('info@pbalife.com', 1),
#  ('info@pbj.org', 1),
#  ('info@pennyappealusa.org', 1),
#  ('info@pharva.com', 1),
#  ('info@pony.org', 1),
#  ('info@prescottmealsonwheels.org', 1),
#  ('info@puenteaz.org', 1),
#  ('info@rescuevillage.org', 1),
#  ('info@restoreaddictionrecovery.com', 1),
#  ('info@restoreelikia.org', 1),
#  ('info@seswa.org', 1),
#  ('info@sevhumanesociety.org', 1),
#  ('info@sinfoniagulfcoast.org', 1),
#  ('info@singlevisioninc.org', 1),
#  ('info@sls.org', 1),
#  ('info@smsresearchfoundation.org', 1),
#  ('info@swfloridawaterpolo.org', 1),
#  ('info@theskillscenter.org', 1),
#  ('info@thinknewmexico.org', 1),
#  ('info@truekids1.org', 1),
#  ('info@usuli.org', 1),
#  ('info@waltonedfoundation.org', 1),
#  ('info@wecanbeheroesfoundation.org', 1),
#  ('info@westvolusiahistoricalsociety.org', 1),
#  ('information@sezarc.com', 1),
#  ('information@sunriseseniorliving.com', 1),
#  ('jana@buildingfamiliesfortomorrow.com', 1),
#  ('jeff@simplysports.net', 1),
#  ('jordanhollins3@gmail.com', 1),
#  ('joy@bcfundofohio.org', 1),
#  ('jray@ngcainc.com', 1),
#  ('kenjonespastor@practicallivingministry.org', 1),
#  ('kim@spacebetween.community', 1),
#  ('ldelk@nextgenerationspeech.org', 1),
#  ('lee.rogers@igworks.org', 1),
#  ('lisa.noss@sigsbee.org', 1),
#  ('lisa@brewhausdogbones.com', 1),
#  ('littlemiracleslearn@gmail.com', 1),
#  ('lnohra@pfva.org', 1),
#  ('love4liamorg@gmail.com', 1),
#  ('lovingcarecatrescue@gmail.com', 1),
#  ('mail@pattyshope.org', 1),
#  ('maliprantis@primehealthcare.com', 1),
#  ('managing@thebrecksvilletheatre.org', 1),
#  ('marianoasis7@gmail.com', 1),
#  ('maumee@insideoutrecreation.com', 1),
#  ('mbasis@wcflfootball.com', 1),
#  ('mbryant@newlife-atl.org', 1),
#  ('membership@biaoh.org', 1),
#  ('michaalrossi@gmail.com', 1),
#  ('michelle@hearts-hands-hope.org', 1),
#  ('mvfc@ptd.net', 1),
#  ('nahsfinfo@gmail.com', 1),
#  ('ncesstarspto@gmail.com', 1),
#  ('nchs@nchsrescue.org', 1),
#  ('nctdclub@gmail.com', 1),
#  ('nicholscenter.recovery@gmail.com', 1),
#  ('nobleworld.info@gmail.com', 1),
#  ('nokillglynncounty@gmail.com', 1),
#  ('northatldance@gmail.com', 1),
#  ('office.anniesartattic@gmail.com', 1),
#  ('office@hth.org', 1),
#  ('office@mbcyorktown.com', 1),
#  ('office@nlfglobal.org', 1),
#  ('officemanager@velouchiusa.com', 1),
#  ('olddominionhumanesociety@gmail.com', 1),
#  ('pageallianceforcommunityaction@gmail.com', 1),
#  ('partneringwithus@fhi360.org', 1),
#  ('pasforglobalhealth@gmail.com', 1),
#  ('pawsofswva@yahoo.com', 1),
#  ('pcollier@wfahec.org', 1),
#  ('pelmore@careersourcesouthwestflorida.com', 1),
#  ('php.fauquier@aol.com', 1),
#  ('pineyriverfiredept@gmail.com', 1),
#  ('pmiller@pleasantviewinc.org', 1),
#  ('poochkabooseinc@gmail.com', 1),
#  ('powedfoundboard@gmail.com', 1),
#  ('prayfirstmm@gmail.com', 1),
#  ('preservation@savewright.org', 1),
#  ('president@ajhsbaseball.org', 1),
#  ('robnpaula@aol.com', 1),
#  ('sam@samnational.org', 1),
#  ('satterlyj@wa.edu', 1),
#  ('sgagliardi@azpta.org', 1),
#  ('sinisterwisdom@gmail.com', 1),
#  ('socialmedia@firdeusfriends.org', 1),
#  ('sophiescircledogrescue@gmail.com', 1),
#  ('southernbirthjustice@gmail.com', 1),
#  ('southtexasbobwhite@texasbrigades.org', 1),
#  ('station17polk@gmail.com', 1),
#  ('support@clubrunner.ca', 1),
#  ('support@hrhn.org', 1),
#  ('support@objectivestandard.org', 1),
#  ('tamar@treenm.org', 1),
#  ('tami@helpadiabeticchild.org', 1),
#  ('thebridge@tbotw.org', 1),
#  ('theoreader@gmail.com', 1),
#  ('thinktreesnm@gmail.com', 1),
#  ('tkyyhd@aol.com', 1),
#  ('toytraindepot.nm@gmail.com', 1),
#  ('troy_forte@carrcares.org', 1),
#  ('ttgraves2015@icloud.com', 1),
#  ('tucmainstreetdirector@gmail.com', 1),
#  ('victoria.n@westcitrussoccer.com', 1),
#  ('volunteer@powhatanva.gov', 1),
#  ('wayne.price@schfbrevard.org', 1),
#  ('whatifworks@gmail.com', 1),
#  ('winnerscirclecharities@gmail.com', 1),
#  ('wpbrotaryclub@gmail.com', 1),
#  ('zander@forestguild.org', 1),
#  ('bbhhsaa@gmail.com', 1),
#  ('bhoward@friendsofthecoronado.org', 1),
#  ('cassie.jones@epiphanyschoolofcharlotte.com', 1),
#  ('cassiesplace@yahoo.com', 1),
#  ('ethan@logmichiana.org', 1),
#  ('friendsofsauganashnews@gmail.com', 1),
#  ('hamtramckhistory@gmail.com', 1),
#  ('hello@solidrockflorida.org', 1),
#  ('inc_footprints@yahoo.com', 1),
#  ('info@buckfever.org', 1),
#  ('info@elkinvalleytrails.org', 1),
#  ('info@emancipatenc.org', 1),
#  ('info@floridajewishacademy.org', 1),
#  ('info@franciscanworks.org', 1),
#  ('info@friendsofmichigan.org', 1),
#  ('info@highwayconnections.org', 1),
#  ('info@lblax.org', 1),
#  ('info@migrosaid.org', 1),
#  ('info@ohacenter.org', 1),
#  ('info@ourcommunityplace.org', 1),
#  ('info@prakashministries.com', 1),
#  ('info@smbs.org', 1),
#  ('info@v2ga.org', 1),
#  ('janetflomax@icloud.com', 1),
#  ('newtown193@gmail.com', 1),
#  ('nsm@nextstepministries.net', 1),
#  ('nyaa.information@yahoo.com', 1),
#  ('piedmontcharitablefoundation@gmail.com', 1),
#  ('sahummel@ptd.net', 1),
#  ('stacyg@newtonclc.com', 1),
#  ('stephanie@letsthrivenm.org', 1),
#  ('sundax@gmail.com', 1),
#  ('t.conway@ewrunnerctr.org', 1),
#  ('terry@a2ministries.com', 1),
#  ('thecoleys@labridocumentary.com', 1),
#  ('ttouhy@chicagoriver.org', 1),
#  ('westbrookepto@gmail.com', 1)]

# %%
# Created a new dataframe with the sorted data
sorted_ss_df = pd.DataFrame(columns = ["Email address", "First name", "Last name", "Company","Opened At"])
for item in sorted_emails:
   entry = ss_df[ss_df["Email address"] == item[0]]
   sorted_ss_df = pd.concat([sorted_ss_df,entry])

sorted_ss_df
# Out:
#                       Email address First name  Last name  \
# 126    info@benefitcostanalysis.org      Glenn  Blomquist
# 127    info@benefitcostanalysis.org      Glenn  Blomquist
# 128    info@benefitcostanalysis.org      Glenn  Blomquist
# 129    info@benefitcostanalysis.org      Glenn  Blomquist
# 130    info@benefitcostanalysis.org      Glenn  Blomquist
# ..                              ...        ...        ...
# 55         t.conway@ewrunnerctr.org     Travis     Conway
# 56           terry@a2ministries.com      Terry        NaN
# 57   thecoleys@labridocumentary.com    Houston      Coley
# 60          ttouhy@chicagoriver.org        Tim      Touhy
# 61          westbrookepto@gmail.com    Brieann      Byers
#
#                                Company          Opened At  \
# 126  Society for Benefit-Cost Analysis                NaN
# 127  Society for Benefit-Cost Analysis                NaN
# 128  Society for Benefit-Cost Analysis                NaN
# 129  Society for Benefit-Cost Analysis                NaN
# 130  Society for Benefit-Cost Analysis                NaN
# ..                                 ...                ...
# 55   West Jupiter Community Group Inc.   9/27/2024 8:33am
# 56                       A2 MINISTRIES   9/27/2024 8:35pm
# 57                      Art Within Inc   9/27/2024 9:26am
# 60        Friends of the Chicago River  9/27/2024 11:21am
# 61      Westbrooke Elementary Pto Inc.   9/27/2024 7:06pm
#
#                                   Clicked Link Address        Clicked At  \
# 126               https://group22team.com/testimonials  9/25/2024 8:24am
# 127        https://www.instagram.com/group22nonprofit/  9/25/2024 8:24am
# 128  https://calendly.com/marcusgroup22/free-consul...  9/25/2024 8:24am
# 129                         https://www.mowdurham.org/  9/25/2024 8:24am
# 130               https://group22team.com/testimonials  9/25/2024 8:22am
# ..                                                 ...               ...
# 55                                                 NaN               NaN
# 56                                                 NaN               NaN
# 57                                                 NaN               NaN
# 60                                                 NaN               NaN
# 61                                                 NaN               NaN
#
#     Email status
# 126          NaN
# 127          NaN
# 128          NaN
# 129          NaN
# 130          NaN
# ..           ...
# 55           NaN
# 56           NaN
# 57           NaN
# 60           NaN
# 61           NaN
#
# [1381 rows x 8 columns]

# %% [markdown]
# ##### Basic Analysis

# %%
# Calculated percentage of messages opened
not_opened = sorted_ss_df["Opened At"].isna().sum()
total_msg = sorted_ss_df["Opened At"].count()

print(f'{not_opened} out of {total_msg} messages were not opened')
print(f'{(not_opened/total_msg).round(2)}% of messages were not opened, meaning {1-(not_opened/total_msg).round(2)}% of messages were opened')
# Out:
# 425 out of 956 messages were not opened
# 0.44% of messages were not opened, meaning 0.56% of messages were opened

# %%
# Found the emails with the highest number of clicks
ss_msg_sort = pd.DataFrame(sorted_emails, columns=["Email", "Number of Click/Opened Data"])
ss_msg_sort
# Out:
#                               Email  Number of Click/Opened Data
# 0      info@benefitcostanalysis.org                           13
# 1           info@pmmifoundation.org                           12
# 2     info@atlantacricketleague.org                           11
# 3            info@wecaremanatee.org                           10
# 4                   fmccs@mccsc.edu                            9
# ..                              ...                          ...
# 548        t.conway@ewrunnerctr.org                            1
# 549          terry@a2ministries.com                            1
# 550  thecoleys@labridocumentary.com                            1
# 551         ttouhy@chicagoriver.org                            1
# 552         westbrookepto@gmail.com                            1
#
# [553 rows x 2 columns]
